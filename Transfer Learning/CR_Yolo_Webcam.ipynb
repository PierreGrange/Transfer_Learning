# %% [markdown]
# # Transfer Learning - TP Applicatif : Yolo live avec une webcam
#
# Dans ce TP, notre objectif est d'utiliser l'algorithme yolo avec différents models préentraînés afin de faire de la reconnaissance d'objets en temps réel. Pour ce faire, nous allons prendre en main la librairie ultralytics et l'associer à la bibliothèque cv2 afin d'utiliser le flux live de la caméra pour reconnaître des entités parmi des catégories comprises dans des modèles différents.
#
# > Découpage des utilisations :
# ## 1 - Modèle yolo V8
# Ce modèle comporte 80 catégories générales, allant de *person* à *toothbrush*. La précision s'en retrouve assez haute car l'algorithme peut difficilement confondre les objets de forme claire. Par exemple, un simple dessin au stylo d'une plante en pot sera reconnu facilement. En revanche, des objets de forme peu classiques ont du mal à être reconnus. Une bouteille au design minimal peut donc être confondu avec une télécommande ou un téléphone.
#
# Le code suivant se charge d'importer les librairies nécessaires au bon fonctionnement de la webcam et de l'algorithme YOLO :

# %%
from ultralytics import YOLO
import cv2
import math

# %% [markdown]
# Ensuite, nous définissons notre modèle, et les classnames (catégories) que notre algorithme va reconnaître :

# %%
# model
model = YOLO("yolo-Weights/yolov8n.pt")

classNames = {0: 'person',
 1: 'bicycle',
 2: 'car',
 3: 'motorcycle',
 4: 'airplane',
 5: 'bus',
 6: 'train',
 7: 'truck',
 8: 'boat',
 9: 'traffic light',
 10: 'fire hydrant',
 11: 'stop sign',
 12: 'parking meter',
 13: 'bench',
 14: 'bird',
 15: 'cat',
 16: 'dog',
 17: 'horse',
 18: 'sheep',
 19: 'cow',
 20: 'elephant',
 21: 'bear',
 22: 'zebra',
 23: 'giraffe',
 24: 'backpack',
 25: 'umbrella',
 26: 'handbag',
 27: 'tie',
 28: 'suitcase',
 29: 'frisbee',
 30: 'skis',
 31: 'snowboard',
 32: 'sports ball',
 33: 'kite',
 34: 'baseball bat',
 35: 'baseball glove',
 36: 'skateboard',
 37: 'surfboard',
 38: 'tennis racket',
 39: 'bottle',
 40: 'wine glass',
 41: 'cup',
 42: 'fork',
 43: 'knife',
 44: 'spoon',
 45: 'bowl',
 46: 'banana',
 47: 'apple',
 48: 'sandwich',
 49: 'orange',
 50: 'broccoli',
 51: 'carrot',
 52: 'hot dog',
 53: 'pizza',
 54: 'donut',
 55: 'cake',
 56: 'chair',
 57: 'couch',
 58: 'potted plant',
 59: 'bed',
 60: 'dining table',
 61: 'toilet',
 62: 'tv',
 63: 'laptop',
 64: 'mouse',
 65: 'remote',
 66: 'keyboard',
 67: 'cell phone',
 68: 'microwave',
 69: 'oven',
 70: 'toaster',
 71: 'sink',
 72: 'refrigerator',
 73: 'book',
 74: 'clock',
 75: 'vase',
 76: 'scissors',
 77: 'teddy bear',
 78: 'hair drier',
 79: 'toothbrush'}

# %% [markdown]
# Enfin, on lance le flux de la caméra et on lance la boucle de détection principale :

# %%
# start webcam
cap = cv2.VideoCapture(0)
cap.set(3, 640)
cap.set(4, 480)

while True:
    success, img = cap.read()
    results = model(img, stream=True)

    # coordinates
    for r in results:
        boxes = r.boxes

        for box in boxes:
            # bounding box
            x1, y1, x2, y2 = box.xyxy[0]
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)  # convert to int values

            # put box in cam
            cv2.rectangle(img, (x1, y1), (x2, y2), (255, 255, 0), 2)

            # confidence
            confidence = math.ceil((box.conf[0] * 100)) / 100
            print("Confidence --->", confidence)

            # class name
            cls = int(box.cls[0])
            print("Class name -->", classNames[cls])

            # object details
            org = [x1, y1]
            font = cv2.FONT_HERSHEY_SIMPLEX
            fontScale = 1
            color = (255, 0, 0)
            thickness = 2

            cv2.putText(img, classNames[cls] + " : " + str(confidence), org, font, fontScale, color, thickness)

    cv2.imshow('Webcam', img)
    if cv2.waitKey(1) == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 4 persons, 188.3ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.61
# Class name --> person
# Confidence ---> 0.54
# Class name --> person
# Speed: 0.0ms preprocess, 188.3ms inference, 18.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 tie, 1 laptop, 85.9ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.61
# Class name --> person
# Confidence ---> 0.6
# Class name --> laptop
# Confidence ---> 0.5
# Class name --> person
# Confidence ---> 0.48
# Class name --> tie
# Confidence ---> 0.3
# Class name --> person
# Confidence ---> 0.29
# Class name --> person
# Speed: 0.0ms preprocess, 85.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 chair, 1 laptop, 86.4ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.73
# Class name --> laptop
# Confidence ---> 0.72
# Class name --> person
# Confidence ---> 0.63
# Class name --> person
# Confidence ---> 0.55
# Class name --> person
# Confidence ---> 0.38
# Class name --> chair
# Confidence ---> 0.26
# Class name --> person
# Speed: 0.0ms preprocess, 86.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 tie, 1 chair, 1 laptop, 81.1ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.76
# Class name --> laptop
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.6
# Class name --> person
# Confidence ---> 0.37
# Class name --> person
# Confidence ---> 0.28
# Class name --> tie
# Confidence ---> 0.27
# Class name --> chair
# Speed: 0.0ms preprocess, 81.1ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 tie, 1 laptop, 86.3ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.84
# Class name --> laptop
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.69
# Class name --> person
# Confidence ---> 0.66
# Class name --> person
# Confidence ---> 0.46
# Class name --> tie
# Speed: 0.0ms preprocess, 86.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 chair, 1 laptop, 68.1ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.69
# Class name --> laptop
# Confidence ---> 0.69
# Class name --> person
# Confidence ---> 0.65
# Class name --> person
# Confidence ---> 0.64
# Class name --> person
# Confidence ---> 0.52
# Class name --> person
# Confidence ---> 0.32
# Class name --> person
# Confidence ---> 0.27
# Class name --> chair
# Speed: 0.0ms preprocess, 68.1ms inference, 15.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 chair, 83.6ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.69
# Class name --> person
# Confidence ---> 0.66
# Class name --> person
# Confidence ---> 0.58
# Class name --> person
# Confidence ---> 0.41
# Class name --> chair
# Confidence ---> 0.37
# Class name --> person
# Speed: 0.0ms preprocess, 83.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 chair, 1 laptop, 68.1ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.59
# Class name --> person
# Confidence ---> 0.58
# Class name --> person
# Confidence ---> 0.54
# Class name --> person
# Confidence ---> 0.51
# Class name --> chair
# Confidence ---> 0.51
# Class name --> laptop
# Confidence ---> 0.44
# Class name --> person
# Speed: 1.0ms preprocess, 68.1ms inference, 15.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 chair, 1 laptop, 83.6ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.72
# Class name --> laptop
# Confidence ---> 0.68
# Class name --> person
# Confidence ---> 0.66
# Class name --> person
# Confidence ---> 0.57
# Class name --> person
# Confidence ---> 0.42
# Class name --> person
# Confidence ---> 0.34
# Class name --> chair
# Speed: 0.0ms preprocess, 83.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 chair, 83.6ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.62
# Class name --> person
# Confidence ---> 0.45
# Class name --> person
# Confidence ---> 0.35
# Class name --> chair
# Confidence ---> 0.33
# Class name --> person
# Confidence ---> 0.28
# Class name --> person
# Confidence ---> 0.26
# Class name --> person
# Speed: 1.0ms preprocess, 83.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 chair, 86.3ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.72
# Class name --> person
# Confidence ---> 0.72
# Class name --> person
# Confidence ---> 0.68
# Class name --> person
# Confidence ---> 0.65
# Class name --> person
# Confidence ---> 0.41
# Class name --> chair
# Confidence ---> 0.36
# Class name --> person
# Confidence ---> 0.35
# Class name --> person
# Speed: 0.0ms preprocess, 86.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 wine glass, 1 chair, 1 laptop, 88.5ms
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.69
# Class name --> person
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.49
# Class name --> laptop
# Confidence ---> 0.49
# Class name --> chair
# Confidence ---> 0.48
# Class name --> wine glass
# Confidence ---> 0.4
# Class name --> person
# Confidence ---> 0.34
# Class name --> person
# Confidence ---> 0.33
# Class name --> person
# Confidence ---> 0.31
# Class name --> person
# Speed: 0.0ms preprocess, 88.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 laptop, 86.5ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.75
# Class name --> laptop
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.28
# Class name --> person
# Speed: 0.0ms preprocess, 86.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 chair, 68.1ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.52
# Class name --> chair
# Speed: 0.0ms preprocess, 68.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 chair, 86.5ms
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.49
# Class name --> chair
# Confidence ---> 0.38
# Class name --> person
# Confidence ---> 0.33
# Class name --> person
# Speed: 0.0ms preprocess, 86.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 2 laptops, 70.8ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.53
# Class name --> laptop
# Confidence ---> 0.39
# Class name --> person
# Confidence ---> 0.38
# Class name --> person
# Confidence ---> 0.28
# Class name --> laptop
# Speed: 0.0ms preprocess, 70.8ms inference, 15.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 83.2ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.52
# Class name --> person
# Speed: 0.0ms preprocess, 83.2ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 chair, 68.2ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.65
# Class name --> person
# Confidence ---> 0.63
# Class name --> person
# Confidence ---> 0.31
# Class name --> chair
# Speed: 0.0ms preprocess, 68.2ms inference, 15.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 chair, 68.8ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.65
# Class name --> person
# Confidence ---> 0.36
# Class name --> person
# Confidence ---> 0.28
# Class name --> chair
# Speed: 0.0ms preprocess, 68.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 chair, 72.5ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.63
# Class name --> person
# Confidence ---> 0.37
# Class name --> chair
# Speed: 0.0ms preprocess, 72.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 chair, 85.9ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.72
# Class name --> person
# Confidence ---> 0.62
# Class name --> person
# Confidence ---> 0.36
# Class name --> chair
# Speed: 1.3ms preprocess, 85.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 chair, 62.7ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.55
# Class name --> person
# Confidence ---> 0.42
# Class name --> chair
# Speed: 0.0ms preprocess, 62.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 chair, 68.1ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.66
# Class name --> person
# Confidence ---> 0.4
# Class name --> chair
# Speed: 0.0ms preprocess, 68.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 69.2ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.64
# Class name --> person
# Speed: 0.0ms preprocess, 69.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 cell phone, 69.2ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.57
# Class name --> person
# Confidence ---> 0.28
# Class name --> cell phone
# Speed: 0.0ms preprocess, 69.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 chair, 84.5ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.63
# Class name --> person
# Confidence ---> 0.3
# Class name --> chair
# Speed: 0.0ms preprocess, 84.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 68.1ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.59
# Class name --> person
# Speed: 0.0ms preprocess, 68.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 76.1ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.72
# Class name --> person
# Confidence ---> 0.59
# Class name --> person
# Speed: 0.0ms preprocess, 76.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 90.3ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.55
# Class name --> person
# Confidence ---> 0.28
# Class name --> person
# Speed: 0.0ms preprocess, 90.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 67.8ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.69
# Class name --> person
# Confidence ---> 0.59
# Class name --> person
# Speed: 0.0ms preprocess, 67.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 73.8ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.68
# Class name --> person
# Confidence ---> 0.38
# Class name --> person
# Speed: 0.0ms preprocess, 73.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 70.2ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.65
# Class name --> person
# Confidence ---> 0.58
# Class name --> person
# Speed: 0.0ms preprocess, 70.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 chair, 67.6ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.66
# Class name --> person
# Confidence ---> 0.58
# Class name --> person
# Confidence ---> 0.26
# Class name --> chair
# Speed: 0.0ms preprocess, 67.6ms inference, 15.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 86.0ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.69
# Class name --> person
# Confidence ---> 0.64
# Class name --> person
# Speed: 0.0ms preprocess, 86.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 chair, 85.9ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.65
# Class name --> person
# Confidence ---> 0.65
# Class name --> person
# Confidence ---> 0.37
# Class name --> chair
# Speed: 0.0ms preprocess, 85.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 chair, 86.0ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.63
# Class name --> person
# Confidence ---> 0.63
# Class name --> person
# Confidence ---> 0.41
# Class name --> chair
# Speed: 0.0ms preprocess, 86.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 chair, 67.6ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.59
# Class name --> person
# Confidence ---> 0.58
# Class name --> person
# Confidence ---> 0.33
# Class name --> chair
# Speed: 0.0ms preprocess, 67.6ms inference, 15.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 chair, 91.8ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.66
# Class name --> person
# Confidence ---> 0.6
# Class name --> person
# Confidence ---> 0.3
# Class name --> chair
# Speed: 0.0ms preprocess, 91.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 chair, 69.3ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.66
# Class name --> person
# Confidence ---> 0.65
# Class name --> person
# Confidence ---> 0.38
# Class name --> chair
# Speed: 0.0ms preprocess, 69.3ms inference, 16.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 chair, 88.4ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.68
# Class name --> person
# Confidence ---> 0.59
# Class name --> person
# Confidence ---> 0.39
# Class name --> chair
# Speed: 0.0ms preprocess, 88.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 chair, 68.7ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.63
# Class name --> person
# Confidence ---> 0.58
# Class name --> person
# Confidence ---> 0.41
# Class name --> chair
# Speed: 0.0ms preprocess, 68.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 chair, 91.7ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.64
# Class name --> person
# Confidence ---> 0.64
# Class name --> person
# Confidence ---> 0.36
# Class name --> chair
# Speed: 0.0ms preprocess, 91.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 chair, 83.7ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.72
# Class name --> person
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.59
# Class name --> person
# Confidence ---> 0.26
# Class name --> chair
# Speed: 0.0ms preprocess, 83.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 67.7ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.63
# Class name --> person
# Confidence ---> 0.61
# Class name --> person
# Speed: 0.0ms preprocess, 67.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 chair, 69.9ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.6
# Class name --> person
# Confidence ---> 0.53
# Class name --> person
# Confidence ---> 0.41
# Class name --> person
# Confidence ---> 0.4
# Class name --> chair
# Speed: 0.0ms preprocess, 69.9ms inference, 8.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 chair, 76.9ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.63
# Class name --> person
# Confidence ---> 0.61
# Class name --> person
# Confidence ---> 0.34
# Class name --> chair
# Speed: 0.0ms preprocess, 76.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 chair, 76.7ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.63
# Class name --> person
# Confidence ---> 0.62
# Class name --> person
# Confidence ---> 0.28
# Class name --> chair
# Speed: 0.0ms preprocess, 76.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 chair, 75.2ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.66
# Class name --> person
# Confidence ---> 0.44
# Class name --> person
# Confidence ---> 0.39
# Class name --> chair
# Speed: 0.0ms preprocess, 75.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 chair, 83.7ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.64
# Class name --> person
# Confidence ---> 0.59
# Class name --> person
# Confidence ---> 0.38
# Class name --> chair
# Speed: 0.0ms preprocess, 83.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 chair, 67.7ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.54
# Class name --> person
# Confidence ---> 0.49
# Class name --> chair
# Speed: 0.0ms preprocess, 67.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 bottle, 1 chair, 67.9ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.67
# Class name --> bottle
# Confidence ---> 0.66
# Class name --> person
# Confidence ---> 0.6
# Class name --> person
# Confidence ---> 0.31
# Class name --> chair
# Speed: 0.0ms preprocess, 67.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 bottle, 1 chair, 74.6ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.72
# Class name --> person
# Confidence ---> 0.64
# Class name --> person
# Confidence ---> 0.54
# Class name --> person
# Confidence ---> 0.46
# Class name --> bottle
# Confidence ---> 0.34
# Class name --> chair
# Speed: 0.0ms preprocess, 74.6ms inference, 15.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 chair, 86.0ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.5
# Class name --> person
# Confidence ---> 0.42
# Class name --> chair
# Speed: 0.0ms preprocess, 86.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 chair, 87.4ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.58
# Class name --> person
# Confidence ---> 0.3
# Class name --> chair
# Confidence ---> 0.28
# Class name --> person
# Speed: 1.0ms preprocess, 87.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 chair, 67.8ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.63
# Class name --> person
# Confidence ---> 0.56
# Class name --> person
# Confidence ---> 0.33
# Class name --> chair
# Speed: 0.0ms preprocess, 67.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 chair, 81.2ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.57
# Class name --> person
# Confidence ---> 0.54
# Class name --> person
# Confidence ---> 0.46
# Class name --> person
# Confidence ---> 0.35
# Class name --> chair
# Speed: 0.0ms preprocess, 81.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 chair, 77.7ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.6
# Class name --> person
# Confidence ---> 0.55
# Class name --> person
# Confidence ---> 0.36
# Class name --> chair
# Speed: 0.0ms preprocess, 77.7ms inference, 15.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 chair, 82.8ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.69
# Class name --> person
# Confidence ---> 0.55
# Class name --> chair
# Confidence ---> 0.39
# Class name --> person
# Speed: 0.0ms preprocess, 82.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 83.3ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.56
# Class name --> person
# Confidence ---> 0.54
# Class name --> person
# Speed: 0.0ms preprocess, 83.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 chair, 71.6ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.48
# Class name --> chair
# Confidence ---> 0.45
# Class name --> person
# Speed: 0.0ms preprocess, 71.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 chair, 72.7ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.65
# Class name --> person
# Confidence ---> 0.54
# Class name --> person
# Confidence ---> 0.45
# Class name --> chair
# Speed: 0.0ms preprocess, 72.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 73.8ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.66
# Class name --> person
# Confidence ---> 0.51
# Class name --> person
# Speed: 0.0ms preprocess, 73.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 chair, 75.3ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.65
# Class name --> person
# Confidence ---> 0.49
# Class name --> person
# Confidence ---> 0.34
# Class name --> chair
# Speed: 0.0ms preprocess, 75.3ms inference, 11.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 chair, 1 remote, 78.3ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.63
# Class name --> person
# Confidence ---> 0.45
# Class name --> chair
# Confidence ---> 0.42
# Class name --> person
# Confidence ---> 0.36
# Class name --> remote
# Speed: 0.0ms preprocess, 78.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 chair, 84.4ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.35
# Class name --> person
# Confidence ---> 0.28
# Class name --> chair
# Speed: 0.0ms preprocess, 84.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 remote, 77.4ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.6
# Class name --> person
# Confidence ---> 0.4
# Class name --> person
# Confidence ---> 0.34
# Class name --> remote
# Confidence ---> 0.28
# Class name --> person
# Speed: 0.0ms preprocess, 77.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 chair, 1 cell phone, 88.0ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.69
# Class name --> person
# Confidence ---> 0.47
# Class name --> person
# Confidence ---> 0.41
# Class name --> cell phone
# Confidence ---> 0.4
# Class name --> chair
# Speed: 0.0ms preprocess, 88.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 chair, 1 cell phone, 67.6ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.72
# Class name --> person
# Confidence ---> 0.65
# Class name --> person
# Confidence ---> 0.45
# Class name --> person
# Confidence ---> 0.44
# Class name --> chair
# Confidence ---> 0.35
# Class name --> cell phone
# Speed: 0.0ms preprocess, 67.6ms inference, 16.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 83.3ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.63
# Class name --> person
# Confidence ---> 0.51
# Class name --> person
# Speed: 0.0ms preprocess, 83.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 87.4ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.72
# Class name --> person
# Confidence ---> 0.61
# Class name --> person
# Confidence ---> 0.36
# Class name --> person
# Confidence ---> 0.27
# Class name --> person
# Speed: 0.0ms preprocess, 87.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 84.1ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.61
# Class name --> person
# Confidence ---> 0.49
# Class name --> person
# Speed: 0.0ms preprocess, 84.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 82.2ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.63
# Class name --> person
# Confidence ---> 0.49
# Class name --> person
# Speed: 0.0ms preprocess, 82.2ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 68.8ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.55
# Class name --> person
# Confidence ---> 0.38
# Class name --> person
# Speed: 0.0ms preprocess, 68.8ms inference, 9.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 85.0ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.69
# Class name --> person
# Confidence ---> 0.54
# Class name --> person
# Confidence ---> 0.49
# Class name --> person
# Confidence ---> 0.39
# Class name --> person
# Speed: 0.0ms preprocess, 85.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 donut, 68.0ms
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.59
# Class name --> person
# Confidence ---> 0.52
# Class name --> person
# Confidence ---> 0.29
# Class name --> donut
# Speed: 0.0ms preprocess, 68.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 donut, 82.2ms
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.52
# Class name --> person
# Confidence ---> 0.34
# Class name --> donut
# Confidence ---> 0.28
# Class name --> person
# Confidence ---> 0.26
# Class name --> person
# Speed: 0.0ms preprocess, 82.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 donut, 68.7ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.8
# Class name --> person
# Confidence ---> 0.76
# Class name --> donut
# Confidence ---> 0.63
# Class name --> person
# Confidence ---> 0.38
# Class name --> person
# Speed: 0.0ms preprocess, 68.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 donut, 69.9ms
# Confidence ---> 0.83
# Class name --> donut
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.58
# Class name --> person
# Speed: 0.0ms preprocess, 69.9ms inference, 15.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 donut, 71.5ms
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.59
# Class name --> person
# Confidence ---> 0.47
# Class name --> donut
# Speed: 0.0ms preprocess, 71.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 donut, 85.1ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.47
# Class name --> donut
# Confidence ---> 0.3
# Class name --> person
# Speed: 0.0ms preprocess, 85.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 83.3ms
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.65
# Class name --> person
# Confidence ---> 0.64
# Class name --> person
# Speed: 0.0ms preprocess, 83.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 remote, 86.0ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.69
# Class name --> person
# Confidence ---> 0.33
# Class name --> remote
# Speed: 0.0ms preprocess, 86.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 83.3ms
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.64
# Class name --> person
# Confidence ---> 0.36
# Class name --> person
# Speed: 0.0ms preprocess, 83.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 67.6ms
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.59
# Class name --> person
# Confidence ---> 0.43
# Class name --> person
# Speed: 0.0ms preprocess, 67.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 remote, 68.2ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.58
# Class name --> person
# Confidence ---> 0.36
# Class name --> person
# Confidence ---> 0.32
# Class name --> remote
# Speed: 0.0ms preprocess, 68.2ms inference, 15.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 86.4ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.69
# Class name --> person
# Confidence ---> 0.62
# Class name --> person
# Confidence ---> 0.41
# Class name --> person
# Speed: 0.0ms preprocess, 86.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 68.1ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.52
# Class name --> person
# Speed: 0.0ms preprocess, 68.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 76.3ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.54
# Class name --> person
# Confidence ---> 0.37
# Class name --> person
# Confidence ---> 0.27
# Class name --> person
# Speed: 0.0ms preprocess, 76.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 85.9ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.8
# Class name --> person
# Confidence ---> 0.56
# Class name --> person
# Confidence ---> 0.44
# Class name --> person
# Speed: 0.0ms preprocess, 85.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 86.1ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.63
# Class name --> person
# Confidence ---> 0.37
# Class name --> person
# Speed: 0.0ms preprocess, 86.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 87.9ms
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.63
# Class name --> person
# Confidence ---> 0.45
# Class name --> person
# Speed: 0.0ms preprocess, 87.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 86.4ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.62
# Class name --> person
# Confidence ---> 0.49
# Class name --> person
# Confidence ---> 0.32
# Class name --> person
# Speed: 0.0ms preprocess, 86.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 89.8ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.69
# Class name --> person
# Confidence ---> 0.59
# Class name --> person
# Confidence ---> 0.35
# Class name --> person
# Speed: 0.0ms preprocess, 89.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 chair, 65.6ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.69
# Class name --> person
# Confidence ---> 0.63
# Class name --> person
# Confidence ---> 0.52
# Class name --> person
# Confidence ---> 0.39
# Class name --> person
# Confidence ---> 0.29
# Class name --> chair
# Speed: 0.0ms preprocess, 65.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 84.3ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.68
# Class name --> person
# Confidence ---> 0.65
# Class name --> person
# Confidence ---> 0.52
# Class name --> person
# Speed: 0.0ms preprocess, 84.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 67.7ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.62
# Class name --> person
# Confidence ---> 0.49
# Class name --> person
# Confidence ---> 0.31
# Class name --> person
# Speed: 0.0ms preprocess, 67.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 72.7ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.62
# Class name --> person
# Confidence ---> 0.51
# Class name --> person
# Confidence ---> 0.31
# Class name --> person
# Speed: 0.0ms preprocess, 72.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 86.9ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.66
# Class name --> person
# Confidence ---> 0.47
# Class name --> person
# Confidence ---> 0.45
# Class name --> person
# Speed: 0.0ms preprocess, 86.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 86.2ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.66
# Class name --> person
# Confidence ---> 0.54
# Class name --> person
# Confidence ---> 0.46
# Class name --> person
# Confidence ---> 0.46
# Class name --> person
# Speed: 0.0ms preprocess, 86.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 87.3ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.58
# Class name --> person
# Confidence ---> 0.49
# Class name --> person
# Confidence ---> 0.34
# Class name --> person
# Speed: 0.0ms preprocess, 87.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 71.6ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.6
# Class name --> person
# Confidence ---> 0.4
# Class name --> person
# Speed: 0.0ms preprocess, 71.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 67.6ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.63
# Class name --> person
# Confidence ---> 0.39
# Class name --> person
# Speed: 0.0ms preprocess, 67.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 85.8ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.6
# Class name --> person
# Confidence ---> 0.43
# Class name --> person
# Speed: 1.0ms preprocess, 85.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 67.6ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.69
# Class name --> person
# Confidence ---> 0.66
# Class name --> person
# Confidence ---> 0.46
# Class name --> person
# Speed: 0.0ms preprocess, 67.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 83.5ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.66
# Class name --> person
# Confidence ---> 0.65
# Class name --> person
# Confidence ---> 0.41
# Class name --> person
# Confidence ---> 0.35
# Class name --> person
# Speed: 0.0ms preprocess, 83.5ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 83.7ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.64
# Class name --> person
# Confidence ---> 0.46
# Class name --> person
# Confidence ---> 0.41
# Class name --> person
# Speed: 1.0ms preprocess, 83.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 85.3ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.68
# Class name --> person
# Confidence ---> 0.4
# Class name --> person
# Confidence ---> 0.26
# Class name --> person
# Speed: 0.0ms preprocess, 85.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 77.7ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.68
# Class name --> person
# Confidence ---> 0.47
# Class name --> person
# Confidence ---> 0.31
# Class name --> person
# Speed: 1.0ms preprocess, 77.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 69.0ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.72
# Class name --> person
# Confidence ---> 0.68
# Class name --> person
# Confidence ---> 0.46
# Class name --> person
# Confidence ---> 0.45
# Class name --> person
# Speed: 1.0ms preprocess, 69.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 83.8ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.53
# Class name --> person
# Confidence ---> 0.39
# Class name --> person
# Speed: 1.0ms preprocess, 83.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 68.0ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.65
# Class name --> person
# Confidence ---> 0.62
# Class name --> person
# Confidence ---> 0.44
# Class name --> person
# Confidence ---> 0.4
# Class name --> person
# Speed: 1.0ms preprocess, 68.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 74.7ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.68
# Class name --> person
# Confidence ---> 0.51
# Class name --> person
# Confidence ---> 0.41
# Class name --> person
# Speed: 0.0ms preprocess, 74.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 chair, 70.2ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.53
# Class name --> person
# Confidence ---> 0.46
# Class name --> person
# Confidence ---> 0.31
# Class name --> chair
# Speed: 0.0ms preprocess, 70.2ms inference, 15.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 86.0ms
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.56
# Class name --> person
# Confidence ---> 0.55
# Class name --> person
# Speed: 0.0ms preprocess, 86.0ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 70.1ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.5
# Class name --> person
# Confidence ---> 0.33
# Class name --> person
# Speed: 0.0ms preprocess, 70.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 83.7ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.68
# Class name --> person
# Confidence ---> 0.64
# Class name --> person
# Confidence ---> 0.58
# Class name --> person
# Confidence ---> 0.51
# Class name --> person
# Speed: 1.0ms preprocess, 83.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 chair, 75.2ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.6
# Class name --> person
# Confidence ---> 0.41
# Class name --> person
# Confidence ---> 0.32
# Class name --> person
# Confidence ---> 0.28
# Class name --> chair
# Speed: 0.0ms preprocess, 75.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 65.5ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.58
# Class name --> person
# Confidence ---> 0.55
# Class name --> person
# Speed: 1.0ms preprocess, 65.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 chair, 68.2ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.65
# Class name --> person
# Confidence ---> 0.52
# Class name --> person
# Confidence ---> 0.35
# Class name --> person
# Confidence ---> 0.3
# Class name --> chair
# Speed: 2.0ms preprocess, 68.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 68.3ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.68
# Class name --> person
# Confidence ---> 0.52
# Class name --> person
# Confidence ---> 0.29
# Class name --> person
# Speed: 1.0ms preprocess, 68.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 86.3ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.61
# Class name --> person
# Confidence ---> 0.48
# Class name --> person
# Confidence ---> 0.41
# Class name --> person
# Speed: 1.0ms preprocess, 86.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 78.3ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.68
# Class name --> person
# Confidence ---> 0.66
# Class name --> person
# Confidence ---> 0.51
# Class name --> person
# Speed: 0.0ms preprocess, 78.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 chair, 68.1ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.69
# Class name --> person
# Confidence ---> 0.63
# Class name --> person
# Confidence ---> 0.4
# Class name --> chair
# Confidence ---> 0.38
# Class name --> person
# Speed: 0.0ms preprocess, 68.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 chair, 1 cell phone, 67.9ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.53
# Class name --> person
# Confidence ---> 0.3
# Class name --> chair
# Confidence ---> 0.26
# Class name --> cell phone
# Speed: 1.0ms preprocess, 67.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 68.5ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.52
# Class name --> person
# Confidence ---> 0.37
# Class name --> person
# Speed: 1.0ms preprocess, 68.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 83.8ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.6
# Class name --> person
# Speed: 0.0ms preprocess, 83.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 chair, 76.6ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.8
# Class name --> person
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.57
# Class name --> person
# Confidence ---> 0.35
# Class name --> chair
# Confidence ---> 0.28
# Class name --> person
# Speed: 2.0ms preprocess, 76.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 85.7ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.59
# Class name --> person
# Confidence ---> 0.55
# Class name --> person
# Speed: 3.5ms preprocess, 85.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 chair, 86.6ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.6
# Class name --> person
# Confidence ---> 0.37
# Class name --> person
# Confidence ---> 0.27
# Class name --> chair
# Speed: 0.0ms preprocess, 86.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 69.1ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.61
# Class name --> person
# Speed: 0.0ms preprocess, 69.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 chair, 66.5ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.68
# Class name --> person
# Confidence ---> 0.65
# Class name --> person
# Confidence ---> 0.46
# Class name --> person
# Confidence ---> 0.27
# Class name --> chair
# Speed: 2.0ms preprocess, 66.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 laptop, 70.7ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.69
# Class name --> person
# Confidence ---> 0.68
# Class name --> person
# Confidence ---> 0.35
# Class name --> laptop
# Confidence ---> 0.31
# Class name --> person
# Speed: 0.0ms preprocess, 70.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 83.1ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.48
# Class name --> person
# Confidence ---> 0.34
# Class name --> person
# Speed: 0.0ms preprocess, 83.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 chair, 1 cell phone, 86.0ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.64
# Class name --> person
# Confidence ---> 0.36
# Class name --> person
# Confidence ---> 0.27
# Class name --> cell phone
# Confidence ---> 0.26
# Class name --> chair
# Speed: 0.0ms preprocess, 86.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 67.7ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.69
# Class name --> person
# ...
# Confidence ---> 0.46
# Class name --> remote
# Confidence ---> 0.45
# Class name --> cell phone
# Confidence ---> 0.35
# Class name --> person
# Speed: 0.0ms preprocess, 171.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 151.6ms
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.32
# Class name --> person
# Speed: 0.0ms preprocess, 151.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 126.3ms
# Confidence ---> 0.47
# Class name --> person
# Confidence ---> 0.29
# Class name --> cell phone
# Speed: 0.0ms preprocess, 126.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 104.8ms
# Confidence ---> 0.26
# Class name --> person
# Speed: 0.0ms preprocess, 104.8ms inference, 15.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 104.7ms
# Speed: 0.0ms preprocess, 104.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 104.9ms
# Speed: 0.0ms preprocess, 104.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 109.7ms
# Speed: 0.0ms preprocess, 109.7ms inference, 8.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 102.1ms
# Speed: 0.0ms preprocess, 102.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 102.2ms
# Speed: 0.0ms preprocess, 102.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 104.8ms
# Speed: 0.0ms preprocess, 104.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 102.2ms
# Speed: 0.0ms preprocess, 102.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 102.1ms
# Speed: 0.0ms preprocess, 102.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 86.4ms
# Speed: 0.0ms preprocess, 86.4ms inference, 15.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 101.7ms
# Speed: 0.0ms preprocess, 101.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 104.8ms
# Confidence ---> 0.36
# Class name --> person
# Speed: 0.0ms preprocess, 104.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 105.6ms
# Speed: 0.0ms preprocess, 105.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 110.7ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 0.0ms preprocess, 110.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 102.3ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.54
# Class name --> person
# Confidence ---> 0.43
# Class name --> person
# Confidence ---> 0.3
# Class name --> person
# Speed: 0.0ms preprocess, 102.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 104.9ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.66
# Class name --> person
# Confidence ---> 0.53
# Class name --> person
# Confidence ---> 0.48
# Class name --> person
# Confidence ---> 0.48
# Class name --> person
# Confidence ---> 0.36
# Class name --> person
# Confidence ---> 0.32
# Class name --> person
# Speed: 0.0ms preprocess, 104.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 laptop, 102.2ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.69
# Class name --> laptop
# Confidence ---> 0.61
# Class name --> person
# Confidence ---> 0.59
# Class name --> person
# Confidence ---> 0.42
# Class name --> person
# Confidence ---> 0.36
# Class name --> person
# Confidence ---> 0.27
# Class name --> person
# Speed: 0.0ms preprocess, 102.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 laptop, 118.0ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.63
# Class name --> person
# Confidence ---> 0.59
# Class name --> laptop
# Confidence ---> 0.52
# Class name --> person
# Confidence ---> 0.38
# Class name --> person
# Confidence ---> 0.28
# Class name --> person
# Speed: 0.0ms preprocess, 118.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 121.1ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.49
# Class name --> person
# Confidence ---> 0.38
# Class name --> person
# Speed: 0.0ms preprocess, 121.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 123.4ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.42
# Class name --> person
# Confidence ---> 0.42
# Class name --> person
# Speed: 0.0ms preprocess, 123.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 102.1ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.5
# Class name --> person
# Confidence ---> 0.3
# Class name --> person
# Speed: 0.0ms preprocess, 102.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 tie, 102.3ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.62
# Class name --> person
# Confidence ---> 0.44
# Class name --> person
# Confidence ---> 0.35
# Class name --> tie
# Confidence ---> 0.26
# Class name --> person
# Speed: 0.0ms preprocess, 102.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 tie, 102.4ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.68
# Class name --> person
# Confidence ---> 0.63
# Class name --> person
# Confidence ---> 0.55
# Class name --> person
# Confidence ---> 0.29
# Class name --> tie
# Confidence ---> 0.27
# Class name --> person
# Speed: 0.0ms preprocess, 102.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 102.1ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.61
# Class name --> person
# Confidence ---> 0.44
# Class name --> person
# Confidence ---> 0.41
# Class name --> person
# Speed: 0.0ms preprocess, 102.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 99.6ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.69
# Class name --> person
# Confidence ---> 0.68
# Class name --> person
# Speed: 0.0ms preprocess, 99.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 107.3ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.63
# Class name --> person
# Confidence ---> 0.43
# Class name --> person
# Confidence ---> 0.31
# Class name --> person
# Speed: 0.0ms preprocess, 107.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 102.1ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.5
# Class name --> person
# Confidence ---> 0.38
# Class name --> person
# Speed: 0.0ms preprocess, 102.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 102.1ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 0.0ms preprocess, 102.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 102.1ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.43
# Class name --> person
# Speed: 0.0ms preprocess, 102.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 104.9ms
# Confidence ---> 0.91
# Class name --> person
# Speed: 0.0ms preprocess, 104.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 90.6ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.69
# Class name --> person
# Confidence ---> 0.61
# Class name --> person
# Confidence ---> 0.38
# Class name --> person
# Speed: 0.0ms preprocess, 90.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 9 persons, 1 laptop, 102.1ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.69
# Class name --> person
# Confidence ---> 0.57
# Class name --> person
# Confidence ---> 0.54
# Class name --> person
# Confidence ---> 0.43
# Class name --> person
# Confidence ---> 0.36
# Class name --> person
# Confidence ---> 0.31
# Class name --> laptop
# Confidence ---> 0.29
# Class name --> person
# Confidence ---> 0.28
# Class name --> person
# Confidence ---> 0.26
# Class name --> person
# Speed: 0.0ms preprocess, 102.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 laptop, 105.0ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.68
# Class name --> person
# Confidence ---> 0.63
# Class name --> person
# Confidence ---> 0.57
# Class name --> person
# Confidence ---> 0.47
# Class name --> laptop
# Confidence ---> 0.43
# Class name --> person
# Speed: 0.0ms preprocess, 105.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 103.7ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.62
# Class name --> person
# Confidence ---> 0.54
# Class name --> person
# Speed: 0.0ms preprocess, 103.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 99.4ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.66
# Class name --> person
# Confidence ---> 0.63
# Class name --> person
# Speed: 0.0ms preprocess, 99.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 102.0ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.68
# Class name --> person
# Speed: 0.0ms preprocess, 102.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 101.6ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.61
# Class name --> person
# Speed: 0.0ms preprocess, 101.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 102.1ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.58
# Class name --> person
# Speed: 0.0ms preprocess, 102.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 99.5ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.66
# Class name --> person
# Confidence ---> 0.58
# Class name --> person
# Speed: 0.0ms preprocess, 99.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 102.2ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.66
# Class name --> person
# Confidence ---> 0.64
# Class name --> person
# Speed: 0.0ms preprocess, 102.2ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 102.0ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.68
# Class name --> person
# Confidence ---> 0.64
# Class name --> person
# Speed: 0.0ms preprocess, 102.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 96.6ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.62
# Class name --> person
# Confidence ---> 0.59
# Class name --> person
# Speed: 0.0ms preprocess, 96.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 11
#       8 results = model(img, stream=True)
#      10 # coordinates
# ---> 11 for r in results:
#      12     boxes = r.boxes
#      14     for box in boxes:
#      15         # bounding box
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\utils\_contextlib.py:36, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      33 try:
#      34     # Issuing `None` to a generator fires it up
#      35     with ctx_factory():
# ---> 36         response = gen.send(None)
#      38     while True:
#      39         try:
#      40             # Forward the response to our caller and get its next request
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ultralytics\engine\predictor.py:275, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     269     self.results[i].speed = {
#     270         "preprocess": profilers[0].dt * 1e3 / n,
#     271         "inference": profilers[1].dt * 1e3 / n,
#     272         "postprocess": profilers[2].dt * 1e3 / n,
#     273     }
#     274     if self.args.verbose or self.args.save or self.args.save_txt or self.args.show:
# --> 275         s[i] += self.write_results(i, Path(paths[i]), im, s)
#     277 # Print batch results
#     278 if self.args.verbose:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ultralytics\engine\predictor.py:335, in BasePredictor.write_results(self, i, p, im, s)
#     333 result = self.results[i]
#     334 result.save_dir = self.save_dir.__str__()  # used in other locations
# --> 335 string += f"{result.verbose()}{result.speed['inference']:.1f}ms"
#     337 # Add predictions to image
#     338 if self.args.save or self.args.show:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ultralytics\engine\results.py:661, in Results.verbose(self)
#     659     log_string += f"{', '.join(f'{self.names[j]} {probs.data[j]:.2f}' for j in probs.top5)}, "
#     660 if boxes:
# --> 661     for c in boxes.cls.unique():
#     662         n = (boxes.cls == c).sum()  # detections per class
#     663         log_string += f"{n} {self.names[int(c)]}{'s' * (n > 1)}, "
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\_tensor.py:934, in Tensor.unique(self, sorted, return_inverse, return_counts, dim)
#     924 if has_torch_function_unary(self):
#     925     return handle_torch_function(
#     926         Tensor.unique,
#     927         (self,),
#    (...)
#     932         dim=dim,
#     933     )
# --> 934 return torch.unique(
#     935     self,
#     936     sorted=sorted,
#     937     return_inverse=return_inverse,
#     938     return_counts=return_counts,
#     939     dim=dim,
#     940 )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\_jit_internal.py:503, in boolean_dispatch.<locals>.fn(*args, **kwargs)
#     501     return if_true(*args, **kwargs)
#     502 else:
# --> 503     return if_false(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\_jit_internal.py:503, in boolean_dispatch.<locals>.fn(*args, **kwargs)
#     501     return if_true(*args, **kwargs)
#     502 else:
# --> 503     return if_false(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\functional.py:997, in _return_output(input, sorted, return_inverse, return_counts, dim)
#     994 if has_torch_function_unary(input):
#     995     return _unique_impl(input, sorted, return_inverse, return_counts, dim)
# --> 997 output, _, _ = _unique_impl(input, sorted, return_inverse, return_counts, dim)
#     998 return output
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\functional.py:911, in _unique_impl(input, sorted, return_inverse, return_counts, dim)
#     903     output, inverse_indices, counts = _VF.unique_dim(
#     904         input,
#     905         dim,
#    (...)
#     908         return_counts=return_counts,
#     909     )
#     910 else:
# --> 911     output, inverse_indices, counts = torch._unique2(
#     912         input,
#     913         sorted=sorted,
#     914         return_inverse=return_inverse,
#     915         return_counts=return_counts,
#     916     )
#     917 return output, inverse_indices, counts
#
# KeyboardInterrupt:

# %% [markdown]
# Le résultat attendu avec un exemple dessiné à la main devrait être similaire à ceci :
# ![potted_plant.png](CR_images/potted_plant.png)

# %% [markdown]
# ## 2 - Modèle YOLO v8n-oiv7
# Ce modèle comporte 601 catégories générales, allant de *Accordion* à *Zucchini*. La précision est moins bonne qu'avec le modèle précédent en raison des nombreuses catégories parfois assez proches (Man / Woman par exemple).
#
# Le code suivant reprend les étapes vues ci-dessus en adaptant au nouveau modèle :

# %%
# model
model = YOLO("yolo-Weights/yolov8n-oiv7.pt")

classNames = ['Accordion', 'Adhesive tape', 'Aircraft', 'Airplane', 'Alarm clock', 'Alpaca', 'Ambulance', 'Animal',
              'Ant', 'Antelope', 'Apple', 'Armadillo', 'Artichoke', 'Auto part', 'Axe', 'Backpack', 'Bagel',
              'Baked goods', 'Balance beam', 'Ball', 'Balloon', 'Banana', 'Band-aid', 'Banjo', 'Barge', 'Barrel',
              'Baseball bat', 'Baseball glove', 'Bat (Animal)', 'Bathroom accessory', 'Bathroom cabinet', 'Bathtub',
              'Beaker', 'Bear', 'Bed', 'Bee', 'Beehive', 'Beer', 'Beetle', 'Bell pepper', 'Belt', 'Bench', 'Bicycle',
              'Bicycle helmet', 'Bicycle wheel', 'Bidet', 'Billboard', 'Billiard table', 'Binoculars', 'Bird',
              'Blender', 'Blue jay', 'Boat', 'Bomb', 'Book', 'Bookcase', 'Boot', 'Bottle', 'Bottle opener',
              'Bow and arrow', 'Bowl', 'Bowling equipment', 'Box', 'Boy', 'Brassiere', 'Bread', 'Briefcase', 'Broccoli',
              'Bronze sculpture', 'Brown bear', 'Building', 'Bull', 'Burrito', 'Bus', 'Bust', 'Butterfly', 'Cabbage',
              'Cabinetry', 'Cake', 'Cake stand', 'Calculator', 'Camel', 'Camera', 'Can opener', 'Canary', 'Candle',
              'Candy', 'Cannon', 'Canoe', 'Cantaloupe', 'Car', 'Carnivore', 'Carrot', 'Cart', 'Cassette deck', 'Castle',
              'Cat', 'Cat furniture', 'Caterpillar', 'Cattle', 'Ceiling fan', 'Cello', 'Centipede', 'Chainsaw', 'Chair',
              'Cheese', 'Cheetah', 'Chest of drawers', 'Chicken', 'Chime', 'Chisel', 'Chopsticks', 'Christmas tree',
              'Clock', 'Closet', 'Clothing', 'Coat', 'Cocktail', 'Cocktail shaker', 'Coconut', 'Coffee', 'Coffee cup',
              'Coffee table', 'Coffeemaker', 'Coin', 'Common fig', 'Common sunflower', 'Computer keyboard',
              'Computer monitor', 'Computer mouse', 'Container', 'Convenience store', 'Cookie', 'Cooking spray',
              'Corded phone', 'Cosmetics', 'Couch', 'Countertop', 'Cowboy hat', 'Crab', 'Cream', 'Cricket ball',
              'Crocodile', 'Croissant', 'Crown', 'Crutch', 'Cucumber', 'Cupboard', 'Curtain', 'Cutting board', 'Dagger',
              'Dairy Product', 'Deer', 'Desk', 'Dessert', 'Diaper', 'Dice', 'Digital clock', 'Dinosaur', 'Dishwasher',
              'Dog', 'Dog bed', 'Doll', 'Dolphin', 'Door', 'Door handle', 'Doughnut', 'Dragonfly', 'Drawer', 'Dress',
              'Drill (Tool)', 'Drink', 'Drinking straw', 'Drum', 'Duck', 'Dumbbell', 'Eagle', 'Earrings', 'Egg (Food)',
              'Elephant', 'Envelope', 'Eraser', 'Face powder', 'Facial tissue holder', 'Falcon', 'Fashion accessory',
              'Fast food', 'Fax', 'Fedora', 'Filing cabinet', 'Fire hydrant', 'Fireplace', 'Fish', 'Flag', 'Flashlight',
              'Flower', 'Flowerpot', 'Flute', 'Flying disc', 'Food', 'Food processor', 'Football', 'Football helmet',
              'Footwear', 'Fork', 'Fountain', 'Fox', 'French fries', 'French horn', 'Frog', 'Fruit', 'Frying pan',
              'Furniture', 'Garden Asparagus', 'Gas stove', 'Giraffe', 'Girl', 'Glasses', 'Glove', 'Goat', 'Goggles',
              'Goldfish', 'Golf ball', 'Golf cart', 'Gondola', 'Goose', 'Grape', 'Grapefruit', 'Grinder', 'Guacamole',
              'Guitar', 'Hair dryer', 'Hair spray', 'Hamburger', 'Hammer', 'Hamster', 'Hand dryer', 'Handbag',
              'Handgun', 'Harbor seal', 'Harmonica', 'Harp', 'Harpsichord', 'Hat', 'Headphones', 'Heater', 'Hedgehog',
              'Helicopter', 'Helmet', 'High heels', 'Hiking equipment', 'Hippopotamus', 'Home appliance', 'Honeycomb',
              'Horizontal bar', 'Horse', 'Hot dog', 'House', 'Houseplant', 'Human arm', 'Human beard', 'Human body',
              'Human ear', 'Human eye', 'Human face', 'Human foot', 'Human hair', 'Human hand', 'Human head',
              'Human leg', 'Human mouth', 'Human nose', 'Humidifier', 'Ice cream', 'Indoor rower', 'Infant bed',
              'Insect', 'Invertebrate', 'Ipod', 'Isopod', 'Jacket', 'Jacuzzi', 'Jaguar (Animal)', 'Jeans', 'Jellyfish',
              'Jet ski', 'Jug', 'Juice', 'Kangaroo', 'Kettle', 'Kitchen & dining room table', 'Kitchen appliance',
              'Kitchen knife', 'Kitchen utensil', 'Kitchenware', 'Kite', 'Knife', 'Koala', 'Ladder', 'Ladle', 'Ladybug',
              'Lamp', 'Land vehicle', 'Lantern', 'Laptop', 'Lavender (Plant)', 'Lemon', 'Leopard', 'Light bulb',
              'Light switch', 'Lighthouse', 'Lily', 'Limousine', 'Lion', 'Lipstick', 'Lizard', 'Lobster', 'Loveseat',
              'Luggage and bags', 'Lynx', 'Magpie', 'Mammal', 'Man', 'Mango', 'Maple', 'Maracas',
              'Marine invertebrates', 'Marine mammal', 'Measuring cup', 'Mechanical fan', 'Medical equipment',
              'Microphone', 'Microwave oven', 'Milk', 'Miniskirt', 'Mirror', 'Missile', 'Mixer', 'Mixing bowl',
              'Mobile phone', 'Monkey', 'Moths and butterflies', 'Motorcycle', 'Mouse', 'Muffin', 'Mug', 'Mule',
              'Mushroom', 'Musical instrument', 'Musical keyboard', 'Nail (Construction)', 'Necklace', 'Nightstand',
              'Oboe', 'Office building', 'Office supplies', 'Orange', 'Organ (Musical Instrument)', 'Ostrich', 'Otter',
              'Oven', 'Owl', 'Oyster', 'Paddle', 'Palm tree', 'Pancake', 'Panda', 'Paper cutter', 'Paper towel',
              'Parachute', 'Parking meter', 'Parrot', 'Pasta', 'Pastry', 'Peach', 'Pear', 'Pen', 'Pencil case',
              'Pencil sharpener', 'Penguin', 'Perfume', 'Person', 'Personal care', 'Personal flotation device', 'Piano',
              'Picnic basket', 'Picture frame', 'Pig', 'Pillow', 'Pineapple', 'Pitcher (Container)', 'Pizza',
              'Pizza cutter', 'Plant', 'Plastic bag', 'Plate', 'Platter', 'Plumbing fixture', 'Polar bear',
              'Pomegranate', 'Popcorn', 'Porch', 'Porcupine', 'Poster', 'Potato', 'Power plugs and sockets',
              'Pressure cooker', 'Pretzel', 'Printer', 'Pumpkin', 'Punching bag', 'Rabbit', 'Raccoon', 'Racket',
              'Radish', 'Ratchet (Device)', 'Raven', 'Rays and skates', 'Red panda', 'Refrigerator', 'Remote control',
              'Reptile', 'Rhinoceros', 'Rifle', 'Ring binder', 'Rocket', 'Roller skates', 'Rose', 'Rugby ball', 'Ruler',
              'Salad', 'Salt and pepper shakers', 'Sandal', 'Sandwich', 'Saucer', 'Saxophone', 'Scale', 'Scarf',
              'Scissors', 'Scoreboard', 'Scorpion', 'Screwdriver', 'Sculpture', 'Sea lion', 'Sea turtle', 'Seafood',
              'Seahorse', 'Seat belt', 'Segway', 'Serving tray', 'Sewing machine', 'Shark', 'Sheep', 'Shelf',
              'Shellfish', 'Shirt', 'Shorts', 'Shotgun', 'Shower', 'Shrimp', 'Sink', 'Skateboard', 'Ski', 'Skirt',
              'Skull', 'Skunk', 'Skyscraper', 'Slow cooker', 'Snack', 'Snail', 'Snake', 'Snowboard', 'Snowman',
              'Snowmobile', 'Snowplow', 'Soap dispenser', 'Sock', 'Sofa bed', 'Sombrero', 'Sparrow', 'Spatula',
              'Spice rack', 'Spider', 'Spoon', 'Sports equipment', 'Sports uniform', 'Squash (Plant)', 'Squid',
              'Squirrel', 'Stairs', 'Stapler', 'Starfish', 'Stationary bicycle', 'Stethoscope', 'Stool', 'Stop sign',
              'Strawberry', 'Street light', 'Stretcher', 'Studio couch', 'Submarine', 'Submarine sandwich', 'Suit',
              'Suitcase', 'Sun hat', 'Sunglasses', 'Surfboard', 'Sushi', 'Swan', 'Swim cap', 'Swimming pool',
              'Swimwear', 'Sword', 'Syringe', 'Table', 'Table tennis racket', 'Tablet computer', 'Tableware', 'Taco',
              'Tank', 'Tap', 'Tart', 'Taxi', 'Tea', 'Teapot', 'Teddy bear', 'Telephone', 'Television', 'Tennis ball',
              'Tennis racket', 'Tent', 'Tiara', 'Tick', 'Tie', 'Tiger', 'Tin can', 'Tire', 'Toaster', 'Toilet',
              'Toilet paper', 'Tomato', 'Tool', 'Toothbrush', 'Torch', 'Tortoise', 'Towel', 'Tower', 'Toy',
              'Traffic light', 'Traffic sign', 'Train', 'Training bench', 'Treadmill', 'Tree', 'Tree house', 'Tripod',
              'Trombone', 'Trousers', 'Truck', 'Trumpet', 'Turkey', 'Turtle', 'Umbrella', 'Unicycle', 'Van', 'Vase',
              'Vegetable', 'Vehicle', 'Vehicle registration plate', 'Violin', 'Volleyball (Ball)', 'Waffle',
              'Waffle iron', 'Wall clock', 'Wardrobe', 'Washing machine', 'Waste container', 'Watch', 'Watercraft',
              'Watermelon', 'Weapon', 'Whale', 'Wheel', 'Wheelchair', 'Whisk', 'Whiteboard', 'Willow', 'Window',
              'Window blind', 'Wine', 'Wine glass', 'Wine rack', 'Winter melon', 'Wok', 'Woman', 'Wood-burning stove',
              'Woodpecker', 'Worm', 'Wrench', 'Zebra', 'Zucchini']

# start webcam
cap = cv2.VideoCapture(0)
cap.set(3, 640)
cap.set(4, 480)

while True:
    success, img = cap.read()
    results = model(img, stream=True)

    # coordinates
    for r in results:
        boxes = r.boxes

        for box in boxes:
            # bounding box
            x1, y1, x2, y2 = box.xyxy[0]
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)  # convert to int values

            # put box in cam
            cv2.rectangle(img, (x1, y1), (x2, y2), (255, 255, 0), 2)

            # confidence
            confidence = math.ceil((box.conf[0] * 100)) / 100
            print("Confidence --->", confidence)

            # class name
            cls = int(box.cls[0])
            print("Class name -->", classNames[cls])

            # object details
            org = [x1, y1]
            font = cv2.FONT_HERSHEY_SIMPLEX
            fontScale = 1
            color = (255, 0, 0)
            thickness = 2

            cv2.putText(img, classNames[cls] + " : " + str(confidence), org, font, fontScale, color, thickness)

    cv2.imshow('Webcam', img)
    if cv2.waitKey(1) == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 1 Clothing, 1 Human face, 1 Man, 151.1ms
# Confidence ---> 0.86
# Class name --> Human face
# Confidence ---> 0.42
# Class name --> Clothing
# Confidence ---> 0.4
# Class name --> Man
# Speed: 0.0ms preprocess, 151.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 4 Human faces, 2 Mans, 120.2ms
# Confidence ---> 0.85
# Class name --> Human face
# Confidence ---> 0.65
# Class name --> Man
# Confidence ---> 0.59
# Class name --> Human face
# Confidence ---> 0.51
# Class name --> Clothing
# Confidence ---> 0.46
# Class name --> Human face
# Confidence ---> 0.44
# Class name --> Man
# Confidence ---> 0.3
# Class name --> Human face
# Speed: 0.0ms preprocess, 120.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 3 Human faces, 2 Mans, 86.4ms
# Confidence ---> 0.85
# Class name --> Human face
# Confidence ---> 0.73
# Class name --> Man
# Confidence ---> 0.67
# Class name --> Human face
# Confidence ---> 0.54
# Class name --> Clothing
# Confidence ---> 0.53
# Class name --> Human face
# Confidence ---> 0.42
# Class name --> Man
# Speed: 0.0ms preprocess, 86.4ms inference, 15.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 3 Human faces, 2 Mans, 1 Woman, 102.0ms
# Confidence ---> 0.86
# Class name --> Human face
# Confidence ---> 0.64
# Class name --> Human face
# Confidence ---> 0.61
# Class name --> Man
# Confidence ---> 0.51
# Class name --> Clothing
# Confidence ---> 0.48
# Class name --> Human face
# Confidence ---> 0.46
# Class name --> Man
# Confidence ---> 0.29
# Class name --> Woman
# Speed: 0.0ms preprocess, 102.0ms inference, 5.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 4 Human faces, 2 Mans, 1 Woman, 106.4ms
# Confidence ---> 0.85
# Class name --> Human face
# Confidence ---> 0.7
# Class name --> Man
# Confidence ---> 0.63
# Class name --> Human face
# Confidence ---> 0.49
# Class name --> Man
# Confidence ---> 0.48
# Class name --> Clothing
# Confidence ---> 0.45
# Class name --> Human face
# Confidence ---> 0.34
# Class name --> Human face
# Confidence ---> 0.3
# Class name --> Woman
# Speed: 1.0ms preprocess, 106.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 4 Human faces, 3 Mans, 1 Woman, 104.1ms
# Confidence ---> 0.86
# Class name --> Human face
# Confidence ---> 0.72
# Class name --> Man
# Confidence ---> 0.63
# Class name --> Human face
# Confidence ---> 0.54
# Class name --> Clothing
# Confidence ---> 0.45
# Class name --> Man
# Confidence ---> 0.44
# Class name --> Human face
# Confidence ---> 0.4
# Class name --> Human face
# Confidence ---> 0.31
# Class name --> Man
# Confidence ---> 0.3
# Class name --> Woman
# Speed: 0.0ms preprocess, 104.1ms inference, 11.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 3 Human faces, 3 Mans, 1 Woman, 102.0ms
# Confidence ---> 0.86
# Class name --> Human face
# Confidence ---> 0.74
# Class name --> Man
# Confidence ---> 0.62
# Class name --> Human face
# Confidence ---> 0.51
# Class name --> Clothing
# Confidence ---> 0.49
# Class name --> Man
# Confidence ---> 0.44
# Class name --> Human face
# Confidence ---> 0.36
# Class name --> Woman
# Confidence ---> 0.34
# Class name --> Man
# Speed: 1.0ms preprocess, 102.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 3 Human faces, 2 Mans, 1 Woman, 102.5ms
# Confidence ---> 0.85
# Class name --> Human face
# Confidence ---> 0.68
# Class name --> Man
# Confidence ---> 0.56
# Class name --> Human face
# Confidence ---> 0.54
# Class name --> Human face
# Confidence ---> 0.46
# Class name --> Clothing
# Confidence ---> 0.44
# Class name --> Man
# Confidence ---> 0.35
# Class name --> Woman
# Speed: 0.0ms preprocess, 102.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 3 Human faces, 2 Mans, 1 Woman, 103.5ms
# Confidence ---> 0.86
# Class name --> Human face
# Confidence ---> 0.71
# Class name --> Man
# Confidence ---> 0.59
# Class name --> Human face
# Confidence ---> 0.55
# Class name --> Human face
# Confidence ---> 0.49
# Class name --> Clothing
# Confidence ---> 0.48
# Class name --> Man
# Confidence ---> 0.33
# Class name --> Woman
# Speed: 0.0ms preprocess, 103.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 3 Human faces, 3 Mans, 1 Woman, 107.7ms
# Confidence ---> 0.85
# Class name --> Human face
# Confidence ---> 0.68
# Class name --> Man
# Confidence ---> 0.58
# Class name --> Human face
# Confidence ---> 0.54
# Class name --> Human face
# Confidence ---> 0.49
# Class name --> Clothing
# Confidence ---> 0.42
# Class name --> Man
# Confidence ---> 0.34
# Class name --> Woman
# Confidence ---> 0.27
# Class name --> Man
# Speed: 1.0ms preprocess, 107.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 3 Human faces, 3 Mans, 102.2ms
# Confidence ---> 0.85
# Class name --> Human face
# Confidence ---> 0.67
# Class name --> Man
# Confidence ---> 0.59
# Class name --> Human face
# Confidence ---> 0.53
# Class name --> Clothing
# Confidence ---> 0.44
# Class name --> Human face
# Confidence ---> 0.38
# Class name --> Man
# Confidence ---> 0.31
# Class name --> Man
# Speed: 0.0ms preprocess, 102.2ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 3 Human faces, 3 Mans, 101.9ms
# Confidence ---> 0.85
# Class name --> Human face
# Confidence ---> 0.65
# Class name --> Man
# Confidence ---> 0.52
# Class name --> Human face
# Confidence ---> 0.48
# Class name --> Clothing
# Confidence ---> 0.46
# Class name --> Human face
# Confidence ---> 0.43
# Class name --> Man
# Confidence ---> 0.35
# Class name --> Man
# Speed: 1.1ms preprocess, 101.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 3 Human faces, 3 Mans, 1 Woman, 104.0ms
# Confidence ---> 0.84
# Class name --> Human face
# Confidence ---> 0.6
# Class name --> Man
# Confidence ---> 0.52
# Class name --> Clothing
# Confidence ---> 0.48
# Class name --> Human face
# Confidence ---> 0.45
# Class name --> Human face
# Confidence ---> 0.44
# Class name --> Man
# Confidence ---> 0.29
# Class name --> Woman
# Confidence ---> 0.27
# Class name --> Man
# Speed: 1.0ms preprocess, 104.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 3 Human faces, 3 Mans, 1 Woman, 102.5ms
# Confidence ---> 0.85
# Class name --> Human face
# Confidence ---> 0.68
# Class name --> Man
# Confidence ---> 0.58
# Class name --> Human face
# Confidence ---> 0.53
# Class name --> Human face
# Confidence ---> 0.51
# Class name --> Clothing
# Confidence ---> 0.44
# Class name --> Man
# Confidence ---> 0.33
# Class name --> Man
# Confidence ---> 0.32
# Class name --> Woman
# Speed: 0.0ms preprocess, 102.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 3 Human faces, 3 Mans, 1 Woman, 101.7ms
# Confidence ---> 0.85
# Class name --> Human face
# Confidence ---> 0.62
# Class name --> Man
# Confidence ---> 0.55
# Class name --> Human face
# Confidence ---> 0.51
# Class name --> Human face
# Confidence ---> 0.51
# Class name --> Clothing
# Confidence ---> 0.4
# Class name --> Man
# Confidence ---> 0.28
# Class name --> Man
# Confidence ---> 0.28
# Class name --> Woman
# Speed: 0.0ms preprocess, 101.7ms inference, 17.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 3 Human faces, 3 Mans, 1 Woman, 120.8ms
# Confidence ---> 0.85
# Class name --> Human face
# Confidence ---> 0.58
# Class name --> Man
# Confidence ---> 0.57
# Class name --> Human face
# Confidence ---> 0.51
# Class name --> Human face
# Confidence ---> 0.48
# Class name --> Clothing
# Confidence ---> 0.39
# Class name --> Woman
# Confidence ---> 0.34
# Class name --> Man
# Confidence ---> 0.33
# Class name --> Man
# Speed: 0.0ms preprocess, 120.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 3 Human faces, 3 Mans, 1 Woman, 103.9ms
# Confidence ---> 0.84
# Class name --> Human face
# Confidence ---> 0.71
# Class name --> Man
# Confidence ---> 0.55
# Class name --> Human face
# Confidence ---> 0.47
# Class name --> Human face
# Confidence ---> 0.45
# Class name --> Man
# Confidence ---> 0.45
# Class name --> Clothing
# Confidence ---> 0.38
# Class name --> Man
# Confidence ---> 0.27
# Class name --> Woman
# Speed: 0.0ms preprocess, 103.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 3 Human faces, 3 Mans, 118.9ms
# Confidence ---> 0.87
# Class name --> Human face
# Confidence ---> 0.72
# Class name --> Man
# Confidence ---> 0.56
# Class name --> Human face
# Confidence ---> 0.5
# Class name --> Clothing
# Confidence ---> 0.49
# Class name --> Human face
# Confidence ---> 0.44
# Class name --> Man
# Confidence ---> 0.37
# Class name --> Man
# Speed: 0.0ms preprocess, 118.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 4 Human faces, 3 Mans, 118.7ms
# Confidence ---> 0.87
# Class name --> Human face
# Confidence ---> 0.74
# Class name --> Man
# Confidence ---> 0.6
# Class name --> Human face
# Confidence ---> 0.49
# Class name --> Clothing
# Confidence ---> 0.46
# Class name --> Man
# Confidence ---> 0.42
# Class name --> Human face
# Confidence ---> 0.3
# Class name --> Human face
# Confidence ---> 0.27
# Class name --> Man
# Speed: 1.0ms preprocess, 118.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 3 Human faces, 3 Mans, 1 Woman, 112.2ms
# Confidence ---> 0.86
# Class name --> Human face
# Confidence ---> 0.72
# Class name --> Man
# Confidence ---> 0.51
# Class name --> Human face
# Confidence ---> 0.51
# Class name --> Human face
# Confidence ---> 0.5
# Class name --> Man
# Confidence ---> 0.48
# Class name --> Clothing
# Confidence ---> 0.31
# Class name --> Woman
# Confidence ---> 0.29
# Class name --> Man
# Speed: 0.0ms preprocess, 112.2ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 5 Human faces, 3 Mans, 99.3ms
# Confidence ---> 0.87
# Class name --> Human face
# Confidence ---> 0.7
# Class name --> Man
# Confidence ---> 0.5
# Class name --> Clothing
# Confidence ---> 0.44
# Class name --> Human face
# Confidence ---> 0.43
# Class name --> Human face
# Confidence ---> 0.43
# Class name --> Man
# Confidence ---> 0.33
# Class name --> Human face
# Confidence ---> 0.27
# Class name --> Man
# Confidence ---> 0.26
# Class name --> Human face
# Speed: 0.1ms preprocess, 99.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 3 Human faces, 3 Mans, 1 Woman, 99.4ms
# Confidence ---> 0.88
# Class name --> Human face
# Confidence ---> 0.74
# Class name --> Man
# Confidence ---> 0.55
# Class name --> Human face
# Confidence ---> 0.47
# Class name --> Clothing
# Confidence ---> 0.45
# Class name --> Human face
# Confidence ---> 0.44
# Class name --> Man
# Confidence ---> 0.29
# Class name --> Man
# Confidence ---> 0.27
# Class name --> Woman
# Speed: 0.0ms preprocess, 99.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 4 Human faces, 3 Mans, 101.8ms
# Confidence ---> 0.86
# Class name --> Human face
# Confidence ---> 0.73
# Class name --> Man
# Confidence ---> 0.5
# Class name --> Clothing
# Confidence ---> 0.47
# Class name --> Human face
# Confidence ---> 0.46
# Class name --> Human face
# Confidence ---> 0.39
# Class name --> Man
# Confidence ---> 0.31
# Class name --> Man
# Confidence ---> 0.3
# Class name --> Human face
# Speed: 0.0ms preprocess, 101.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 3 Human faces, 4 Mans, 83.8ms
# Confidence ---> 0.86
# Class name --> Human face
# Confidence ---> 0.72
# Class name --> Man
# Confidence ---> 0.53
# Class name --> Human face
# Confidence ---> 0.53
# Class name --> Human face
# Confidence ---> 0.5
# Class name --> Clothing
# Confidence ---> 0.47
# Class name --> Man
# Confidence ---> 0.33
# Class name --> Man
# Confidence ---> 0.26
# Class name --> Man
# Speed: 1.0ms preprocess, 83.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 3 Human faces, 3 Mans, 1 Woman, 120.3ms
# Confidence ---> 0.87
# Class name --> Human face
# Confidence ---> 0.7
# Class name --> Man
# Confidence ---> 0.6
# Class name --> Human face
# Confidence ---> 0.52
# Class name --> Human face
# Confidence ---> 0.49
# Class name --> Clothing
# Confidence ---> 0.4
# Class name --> Man
# Confidence ---> 0.32
# Class name --> Woman
# Confidence ---> 0.29
# Class name --> Man
# Speed: 1.0ms preprocess, 120.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 2 Human faces, 3 Mans, 91.3ms
# Confidence ---> 0.84
# Class name --> Human face
# Confidence ---> 0.67
# Class name --> Man
# Confidence ---> 0.54
# Class name --> Human face
# Confidence ---> 0.45
# Class name --> Clothing
# Confidence ---> 0.44
# Class name --> Man
# Confidence ---> 0.29
# Class name --> Man
# Speed: 0.0ms preprocess, 91.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 2 Human faces, 3 Mans, 99.9ms
# Confidence ---> 0.86
# Class name --> Human face
# Confidence ---> 0.67
# Class name --> Man
# Confidence ---> 0.61
# Class name --> Human face
# Confidence ---> 0.44
# Class name --> Clothing
# Confidence ---> 0.4
# Class name --> Man
# Confidence ---> 0.27
# Class name --> Man
# Speed: 1.0ms preprocess, 99.9ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 2 Human faces, 2 Mans, 102.3ms
# Confidence ---> 0.85
# Class name --> Human face
# Confidence ---> 0.69
# Class name --> Man
# Confidence ---> 0.47
# Class name --> Human face
# Confidence ---> 0.46
# Class name --> Clothing
# Confidence ---> 0.44
# Class name --> Man
# Speed: 0.0ms preprocess, 102.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 2 Human faces, 2 Mans, 104.7ms
# Confidence ---> 0.86
# Class name --> Human face
# Confidence ---> 0.7
# Class name --> Man
# Confidence ---> 0.5
# Class name --> Human face
# Confidence ---> 0.46
# Class name --> Clothing
# Confidence ---> 0.45
# Class name --> Man
# Speed: 0.0ms preprocess, 104.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 3 Human faces, 4 Mans, 99.3ms
# Confidence ---> 0.85
# Class name --> Human face
# Confidence ---> 0.69
# Class name --> Man
# Confidence ---> 0.58
# Class name --> Human face
# Confidence ---> 0.47
# Class name --> Clothing
# Confidence ---> 0.37
# Class name --> Man
# Confidence ---> 0.3
# Class name --> Human face
# Confidence ---> 0.3
# Class name --> Man
# Confidence ---> 0.29
# Class name --> Man
# Speed: 1.0ms preprocess, 99.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 2 Human faces, 3 Mans, 86.5ms
# Confidence ---> 0.86
# Class name --> Human face
# Confidence ---> 0.59
# Class name --> Human face
# Confidence ---> 0.53
# Class name --> Man
# Confidence ---> 0.45
# Class name --> Man
# Confidence ---> 0.4
# Class name --> Clothing
# Confidence ---> 0.3
# Class name --> Man
# Speed: 1.1ms preprocess, 86.5ms inference, 15.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 4 Human faces, 3 Mans, 83.6ms
# Confidence ---> 0.88
# Class name --> Human face
# Confidence ---> 0.61
# Class name --> Man
# Confidence ---> 0.58
# Class name --> Human face
# Confidence ---> 0.43
# Class name --> Clothing
# Confidence ---> 0.42
# Class name --> Man
# Confidence ---> 0.41
# Class name --> Human face
# Confidence ---> 0.34
# Class name --> Man
# Confidence ---> 0.32
# Class name --> Human face
# Speed: 1.0ms preprocess, 83.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 4 Human faces, 3 Mans, 1 Woman, 103.1ms
# Confidence ---> 0.87
# Class name --> Human face
# Confidence ---> 0.72
# Class name --> Man
# Confidence ---> 0.57
# Class name --> Human face
# Confidence ---> 0.49
# Class name --> Human face
# Confidence ---> 0.45
# Class name --> Clothing
# Confidence ---> 0.42
# Class name --> Man
# Confidence ---> 0.31
# Class name --> Man
# Confidence ---> 0.29
# Class name --> Human face
# Confidence ---> 0.29
# Class name --> Woman
# Speed: 0.0ms preprocess, 103.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 4 Human faces, 3 Mans, 101.9ms
# Confidence ---> 0.85
# Class name --> Human face
# Confidence ---> 0.69
# Class name --> Man
# Confidence ---> 0.55
# Class name --> Human face
# Confidence ---> 0.44
# Class name --> Clothing
# Confidence ---> 0.43
# Class name --> Man
# Confidence ---> 0.37
# Class name --> Human face
# Confidence ---> 0.36
# Class name --> Human face
# Confidence ---> 0.35
# Class name --> Man
# Speed: 1.0ms preprocess, 101.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 3 Human faces, 3 Mans, 101.0ms
# Confidence ---> 0.86
# Class name --> Human face
# Confidence ---> 0.64
# Class name --> Man
# Confidence ---> 0.51
# Class name --> Human face
# Confidence ---> 0.46
# Class name --> Clothing
# Confidence ---> 0.4
# Class name --> Human face
# Confidence ---> 0.4
# Class name --> Man
# Confidence ---> 0.37
# Class name --> Man
# Speed: 1.0ms preprocess, 101.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 4 Human faces, 3 Mans, 88.5ms
# Confidence ---> 0.88
# Class name --> Human face
# Confidence ---> 0.54
# Class name --> Man
# Confidence ---> 0.52
# Class name --> Human face
# Confidence ---> 0.48
# Class name --> Clothing
# Confidence ---> 0.47
# Class name --> Man
# Confidence ---> 0.43
# Class name --> Human face
# Confidence ---> 0.34
# Class name --> Man
# Confidence ---> 0.33
# Class name --> Human face
# Speed: 0.0ms preprocess, 88.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 3 Human faces, 3 Mans, 102.3ms
# Confidence ---> 0.86
# Class name --> Human face
# Confidence ---> 0.69
# Class name --> Man
# Confidence ---> 0.58
# Class name --> Human face
# Confidence ---> 0.48
# Class name --> Human face
# Confidence ---> 0.43
# Class name --> Clothing
# Confidence ---> 0.43
# Class name --> Man
# Confidence ---> 0.36
# Class name --> Man
# Speed: 0.0ms preprocess, 102.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 5 Human faces, 5 Mans, 1 Woman, 102.0ms
# Confidence ---> 0.87
# Class name --> Human face
# Confidence ---> 0.71
# Class name --> Man
# Confidence ---> 0.58
# Class name --> Human face
# Confidence ---> 0.5
# Class name --> Clothing
# Confidence ---> 0.45
# Class name --> Human face
# Confidence ---> 0.39
# Class name --> Man
# Confidence ---> 0.37
# Class name --> Human face
# Confidence ---> 0.3
# Class name --> Man
# Confidence ---> 0.3
# Class name --> Human face
# Confidence ---> 0.27
# Class name --> Man
# Confidence ---> 0.27
# Class name --> Man
# Confidence ---> 0.27
# Class name --> Woman
# Speed: 0.0ms preprocess, 102.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 4 Human faces, 3 Mans, 102.3ms
# Confidence ---> 0.87
# Class name --> Human face
# Confidence ---> 0.69
# Class name --> Man
# Confidence ---> 0.53
# Class name --> Human face
# Confidence ---> 0.45
# Class name --> Clothing
# Confidence ---> 0.4
# Class name --> Man
# Confidence ---> 0.39
# Class name --> Man
# Confidence ---> 0.35
# Class name --> Human face
# Confidence ---> 0.3
# Class name --> Human face
# Speed: 0.0ms preprocess, 102.3ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 4 Human faces, 3 Mans, 1 Woman, 87.6ms
# Confidence ---> 0.88
# Class name --> Human face
# Confidence ---> 0.66
# Class name --> Man
# Confidence ---> 0.5
# Class name --> Clothing
# Confidence ---> 0.5
# Class name --> Human face
# Confidence ---> 0.47
# Class name --> Man
# Confidence ---> 0.44
# Class name --> Human face
# Confidence ---> 0.42
# Class name --> Human face
# Confidence ---> 0.41
# Class name --> Man
# Confidence ---> 0.29
# Class name --> Woman
# Speed: 0.0ms preprocess, 87.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 4 Human faces, 3 Mans, 104.7ms
# Confidence ---> 0.87
# Class name --> Human face
# Confidence ---> 0.67
# Class name --> Man
# Confidence ---> 0.52
# Class name --> Human face
# Confidence ---> 0.5
# Class name --> Clothing
# Confidence ---> 0.48
# Class name --> Man
# Confidence ---> 0.45
# Class name --> Man
# Confidence ---> 0.36
# Class name --> Human face
# Confidence ---> 0.3
# Class name --> Human face
# Speed: 0.0ms preprocess, 104.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 4 Human faces, 3 Mans, 104.4ms
# Confidence ---> 0.87
# Class name --> Human face
# Confidence ---> 0.63
# Class name --> Man
# Confidence ---> 0.55
# Class name --> Human face
# Confidence ---> 0.5
# Class name --> Clothing
# Confidence ---> 0.46
# Class name --> Human face
# Confidence ---> 0.45
# Class name --> Human face
# Confidence ---> 0.44
# Class name --> Man
# Confidence ---> 0.43
# Class name --> Man
# Speed: 0.0ms preprocess, 104.4ms inference, 15.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 4 Human faces, 3 Mans, 1 Woman, 102.3ms
# Confidence ---> 0.87
# Class name --> Human face
# Confidence ---> 0.69
# Class name --> Man
# Confidence ---> 0.53
# Class name --> Clothing
# Confidence ---> 0.5
# Class name --> Human face
# Confidence ---> 0.49
# Class name --> Man
# Confidence ---> 0.43
# Class name --> Human face
# Confidence ---> 0.43
# Class name --> Man
# Confidence ---> 0.37
# Class name --> Human face
# Confidence ---> 0.29
# Class name --> Woman
# Speed: 0.0ms preprocess, 102.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 5 Human faces, 4 Mans, 117.6ms
# Confidence ---> 0.85
# Class name --> Human face
# Confidence ---> 0.7
# Class name --> Man
# Confidence ---> 0.52
# Class name --> Clothing
# Confidence ---> 0.41
# Class name --> Human face
# Confidence ---> 0.4
# Class name --> Human face
# Confidence ---> 0.37
# Class name --> Man
# Confidence ---> 0.29
# Class name --> Human face
# Confidence ---> 0.29
# Class name --> Human face
# Confidence ---> 0.28
# Class name --> Man
# Confidence ---> 0.27
# Class name --> Man
# Speed: 0.0ms preprocess, 117.6ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 2 Human faces, 1 Man, 102.2ms
# Confidence ---> 0.84
# Class name --> Human face
# Confidence ---> 0.63
# Class name --> Man
# Confidence ---> 0.49
# Class name --> Clothing
# Confidence ---> 0.36
# Class name --> Human face
# Speed: 0.0ms preprocess, 102.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 2 Human faces, 1 Man, 105.0ms
# Confidence ---> 0.87
# Class name --> Human face
# Confidence ---> 0.5
# Class name --> Man
# Confidence ---> 0.47
# Class name --> Clothing
# Confidence ---> 0.34
# Class name --> Human face
# Speed: 0.0ms preprocess, 105.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 1 Human face, 1 Man, 82.8ms
# Confidence ---> 0.92
# Class name --> Human face
# Confidence ---> 0.57
# Class name --> Man
# Confidence ---> 0.34
# Class name --> Clothing
# Speed: 0.0ms preprocess, 82.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 2 Human faces, 1 Man, 102.1ms
# Confidence ---> 0.87
# Class name --> Human face
# Confidence ---> 0.49
# Class name --> Man
# Confidence ---> 0.36
# Class name --> Clothing
# Confidence ---> 0.34
# Class name --> Human face
# Speed: 0.0ms preprocess, 102.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 2 Human faces, 1 Woman, 102.5ms
# Confidence ---> 0.86
# Class name --> Human face
# Confidence ---> 0.33
# Class name --> Human face
# Confidence ---> 0.29
# Class name --> Woman
# Confidence ---> 0.26
# Class name --> Clothing
# Speed: 0.0ms preprocess, 102.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 2 Human faces, 1 Man, 99.4ms
# Confidence ---> 0.86
# Class name --> Human face
# Confidence ---> 0.33
# Class name --> Human face
# Confidence ---> 0.31
# Class name --> Man
# Confidence ---> 0.26
# Class name --> Clothing
# Speed: 0.0ms preprocess, 99.4ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 2 Human faces, 1 Man, 1 Woman, 102.0ms
# Confidence ---> 0.88
# Class name --> Human face
# Confidence ---> 0.36
# Class name --> Man
# Confidence ---> 0.29
# Class name --> Woman
# Confidence ---> 0.26
# Class name --> Human face
# Confidence ---> 0.26
# Class name --> Clothing
# Speed: 0.0ms preprocess, 102.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Human face, 1 Man, 100.3ms
# Confidence ---> 0.87
# Class name --> Human face
# Confidence ---> 0.27
# Class name --> Man
# Speed: 3.5ms preprocess, 100.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 2 Human faces, 1 Man, 1 Woman, 83.6ms
# Confidence ---> 0.86
# Class name --> Human face
# Confidence ---> 0.69
# Class name --> Man
# Confidence ---> 0.47
# Class name --> Human face
# Confidence ---> 0.39
# Class name --> Clothing
# Confidence ---> 0.29
# Class name --> Woman
# Speed: 3.4ms preprocess, 83.6ms inference, 18.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 2 Human faces, 1 Man, 2 Womans, 102.2ms
# Confidence ---> 0.84
# Class name --> Human face
# Confidence ---> 0.47
# Class name --> Clothing
# Confidence ---> 0.44
# Class name --> Human face
# Confidence ---> 0.35
# Class name --> Man
# Confidence ---> 0.3
# Class name --> Woman
# Confidence ---> 0.28
# Class name --> Woman
# Speed: 0.0ms preprocess, 102.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 3 Human faces, 2 Mans, 103.1ms
# Confidence ---> 0.87
# Class name --> Human face
# Confidence ---> 0.59
# Class name --> Man
# Confidence ---> 0.56
# Class name --> Clothing
# Confidence ---> 0.47
# Class name --> Human face
# Confidence ---> 0.4
# Class name --> Man
# Confidence ---> 0.4
# Class name --> Human face
# Speed: 0.0ms preprocess, 103.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 3 Human faces, 2 Mans, 1 Woman, 104.7ms
# Confidence ---> 0.83
# Class name --> Human face
# Confidence ---> 0.71
# Class name --> Man
# Confidence ---> 0.58
# Class name --> Human face
# Confidence ---> 0.58
# Class name --> Clothing
# Confidence ---> 0.54
# Class name --> Human face
# Confidence ---> 0.37
# Class name --> Man
# Confidence ---> 0.31
# Class name --> Woman
# Speed: 0.0ms preprocess, 104.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 3 Human faces, 3 Mans, 100.2ms
# Confidence ---> 0.85
# Class name --> Human face
# Confidence ---> 0.75
# Class name --> Man
# Confidence ---> 0.66
# Class name --> Human face
# Confidence ---> 0.58
# Class name --> Clothing
# Confidence ---> 0.46
# Class name --> Human face
# Confidence ---> 0.42
# Class name --> Man
# Confidence ---> 0.29
# Class name --> Man
# Speed: 0.0ms preprocess, 100.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 3 Human faces, 4 Mans, 104.9ms
# Confidence ---> 0.84
# Class name --> Human face
# Confidence ---> 0.76
# Class name --> Man
# Confidence ---> 0.65
# Class name --> Human face
# Confidence ---> 0.55
# Class name --> Clothing
# Confidence ---> 0.44
# Class name --> Man
# Confidence ---> 0.42
# Class name --> Human face
# Confidence ---> 0.33
# Class name --> Man
# Confidence ---> 0.26
# Class name --> Man
# Speed: 0.0ms preprocess, 104.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 3 Human faces, 3 Mans, 1 Woman, 102.2ms
# Confidence ---> 0.84
# Class name --> Human face
# Confidence ---> 0.76
# Class name --> Man
# Confidence ---> 0.69
# Class name --> Human face
# Confidence ---> 0.55
# Class name --> Clothing
# Confidence ---> 0.43
# Class name --> Man
# Confidence ---> 0.41
# Class name --> Human face
# Confidence ---> 0.33
# Class name --> Man
# Confidence ---> 0.27
# Class name --> Woman
# Speed: 0.0ms preprocess, 102.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 3 Human faces, 3 Mans, 1 Woman, 102.1ms
# Confidence ---> 0.83
# Class name --> Human face
# Confidence ---> 0.74
# Class name --> Man
# Confidence ---> 0.66
# Class name --> Human face
# Confidence ---> 0.52
# Class name --> Clothing
# Confidence ---> 0.48
# Class name --> Human face
# Confidence ---> 0.34
# Class name --> Man
# Confidence ---> 0.28
# Class name --> Man
# Confidence ---> 0.27
# Class name --> Woman
# Speed: 1.0ms preprocess, 102.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 3 Human faces, 3 Mans, 99.4ms
# Confidence ---> 0.84
# Class name --> Human face
# Confidence ---> 0.73
# Class name --> Man
# Confidence ---> 0.66
# Class name --> Human face
# Confidence ---> 0.56
# Class name --> Clothing
# Confidence ---> 0.38
# Class name --> Man
# Confidence ---> 0.36
# Class name --> Human face
# Confidence ---> 0.3
# Class name --> Man
# Speed: 0.0ms preprocess, 99.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 3 Human faces, 5 Mans, 102.2ms
# Confidence ---> 0.87
# Class name --> Human face
# Confidence ---> 0.73
# Class name --> Man
# Confidence ---> 0.67
# Class name --> Human face
# Confidence ---> 0.57
# Class name --> Clothing
# Confidence ---> 0.37
# Class name --> Man
# Confidence ---> 0.36
# Class name --> Human face
# Confidence ---> 0.35
# Class name --> Man
# Confidence ---> 0.32
# Class name --> Man
# Confidence ---> 0.31
# Class name --> Man
# Speed: 0.0ms preprocess, 102.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 3 Human faces, 4 Mans, 102.7ms
# Confidence ---> 0.84
# Class name --> Human face
# Confidence ---> 0.7
# Class name --> Man
# Confidence ---> 0.69
# Class name --> Human face
# Confidence ---> 0.5
# Class name --> Clothing
# Confidence ---> 0.43
# Class name --> Man
# Confidence ---> 0.38
# Class name --> Human face
# Confidence ---> 0.29
# Class name --> Man
# Confidence ---> 0.28
# Class name --> Man
# Speed: 0.0ms preprocess, 102.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 3 Human faces, 5 Mans, 1 Woman, 102.0ms
# Confidence ---> 0.85
# Class name --> Human face
# Confidence ---> 0.74
# Class name --> Man
# Confidence ---> 0.67
# Class name --> Human face
# Confidence ---> 0.55
# Class name --> Clothing
# Confidence ---> 0.41
# Class name --> Man
# Confidence ---> 0.4
# Class name --> Human face
# Confidence ---> 0.33
# Class name --> Man
# Confidence ---> 0.26
# Class name --> Man
# Confidence ---> 0.26
# Class name --> Man
# Confidence ---> 0.26
# Class name --> Woman
# Speed: 0.0ms preprocess, 102.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 3 Human faces, 4 Mans, 102.2ms
# Confidence ---> 0.82
# Class name --> Human face
# Confidence ---> 0.74
# Class name --> Man
# Confidence ---> 0.67
# Class name --> Human face
# Confidence ---> 0.53
# Class name --> Clothing
# Confidence ---> 0.45
# Class name --> Human face
# Confidence ---> 0.4
# Class name --> Man
# Confidence ---> 0.3
# Class name --> Man
# Confidence ---> 0.28
# Class name --> Man
# Speed: 0.0ms preprocess, 102.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 3 Human faces, 4 Mans, 102.1ms
# Confidence ---> 0.83
# Class name --> Human face
# Confidence ---> 0.73
# Class name --> Man
# Confidence ---> 0.67
# Class name --> Human face
# Confidence ---> 0.55
# Class name --> Clothing
# Confidence ---> 0.45
# Class name --> Man
# Confidence ---> 0.35
# Class name --> Human face
# Confidence ---> 0.29
# Class name --> Man
# Confidence ---> 0.28
# Class name --> Man
# Speed: 0.0ms preprocess, 102.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 3 Human faces, 4 Mans, 1 Woman, 100.2ms
# Confidence ---> 0.84
# Class name --> Human face
# Confidence ---> 0.65
# Class name --> Human face
# Confidence ---> 0.62
# Class name --> Man
# Confidence ---> 0.53
# Class name --> Clothing
# Confidence ---> 0.47
# Class name --> Human face
# Confidence ---> 0.39
# Class name --> Man
# Confidence ---> 0.36
# Class name --> Man
# Confidence ---> 0.26
# Class name --> Man
# Confidence ---> 0.26
# Class name --> Woman
# Speed: 0.0ms preprocess, 100.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 3 Human faces, 2 Mans, 102.0ms
# Confidence ---> 0.86
# Class name --> Human face
# Confidence ---> 0.52
# Class name --> Human face
# Confidence ---> 0.48
# Class name --> Man
# Confidence ---> 0.4
# Class name --> Man
# Confidence ---> 0.36
# Class name --> Clothing
# Confidence ---> 0.29
# Class name --> Human face
# Speed: 0.0ms preprocess, 102.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 3 Human faces, 2 Mans, 1 Woman, 102.0ms
# Confidence ---> 0.84
# Class name --> Human face
# Confidence ---> 0.59
# Class name --> Human face
# Confidence ---> 0.49
# Class name --> Man
# Confidence ---> 0.41
# Class name --> Human face
# Confidence ---> 0.38
# Class name --> Clothing
# Confidence ---> 0.37
# Class name --> Man
# Confidence ---> 0.33
# Class name --> Woman
# Speed: 0.0ms preprocess, 102.0ms inference, 12.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 3 Human faces, 3 Mans, 1 Woman, 86.1ms
# Confidence ---> 0.85
# Class name --> Human face
# Confidence ---> 0.61
# Class name --> Human face
# Confidence ---> 0.53
# Class name --> Human face
# Confidence ---> 0.48
# Class name --> Man
# Confidence ---> 0.47
# Class name --> Clothing
# Confidence ---> 0.34
# Class name --> Man
# Confidence ---> 0.34
# Class name --> Woman
# Confidence ---> 0.33
# Class name --> Man
# Speed: 0.0ms preprocess, 86.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 3 Human faces, 3 Mans, 103.3ms
# Confidence ---> 0.86
# Class name --> Human face
# Confidence ---> 0.64
# Class name --> Human face
# Confidence ---> 0.54
# Class name --> Human face
# Confidence ---> 0.49
# Class name --> Clothing
# Confidence ---> 0.37
# Class name --> Man
# Confidence ---> 0.3
# Class name --> Man
# Confidence ---> 0.27
# Class name --> Man
# Speed: 0.0ms preprocess, 103.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 2 Human faces, 1 Man, 86.3ms
# Confidence ---> 0.78
# Class name --> Human face
# Confidence ---> 0.45
# Class name --> Man
# Confidence ---> 0.35
# Class name --> Human face
# Confidence ---> 0.31
# Class name --> Clothing
# Speed: 0.0ms preprocess, 86.3ms inference, 15.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 3 Human faces, 1 Man, 102.6ms
# Confidence ---> 0.83
# Class name --> Human face
# Confidence ---> 0.49
# Class name --> Human face
# Confidence ---> 0.4
# Class name --> Human face
# Confidence ---> 0.38
# Class name --> Clothing
# Confidence ---> 0.37
# Class name --> Man
# Speed: 0.0ms preprocess, 102.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 2 Human faces, 3 Mans, 102.0ms
# Confidence ---> 0.8
# Class name --> Human face
# Confidence ---> 0.56
# Class name --> Man
# Confidence ---> 0.4
# Class name --> Clothing
# Confidence ---> 0.4
# Class name --> Man
# Confidence ---> 0.33
# Class name --> Man
# Confidence ---> 0.3
# Class name --> Human face
# Speed: 0.0ms preprocess, 102.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 3 Human faces, 3 Mans, 101.6ms
# Confidence ---> 0.82
# Class name --> Human face
# Confidence ---> 0.67
# Class name --> Man
# Confidence ---> 0.47
# Class name --> Clothing
# Confidence ---> 0.46
# Class name --> Human face
# Confidence ---> 0.36
# Class name --> Man
# Confidence ---> 0.33
# Class name --> Human face
# Confidence ---> 0.31
# Class name --> Man
# Speed: 0.0ms preprocess, 101.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 2 Human faces, 3 Mans, 102.6ms
# Confidence ---> 0.84
# Class name --> Human face
# Confidence ---> 0.65
# Class name --> Man
# Confidence ---> 0.49
# Class name --> Human face
# Confidence ---> 0.48
# Class name --> Man
# Confidence ---> 0.46
# Class name --> Clothing
# Confidence ---> 0.31
# Class name --> Man
# Speed: 0.0ms preprocess, 102.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 2 Human faces, 2 Mans, 102.0ms
# Confidence ---> 0.8
# Class name --> Human face
# Confidence ---> 0.56
# Class name --> Man
# Confidence ---> 0.46
# Class name --> Human face
# Confidence ---> 0.39
# Class name --> Man
# Confidence ---> 0.32
# Class name --> Clothing
# Speed: 0.0ms preprocess, 102.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 3 Human faces, 2 Mans, 100.6ms
# Confidence ---> 0.74
# Class name --> Human face
# Confidence ---> 0.56
# Class name --> Man
# Confidence ---> 0.42
# Class name --> Human face
# Confidence ---> 0.37
# Class name --> Man
# Confidence ---> 0.29
# Class name --> Human face
# Confidence ---> 0.27
# Class name --> Clothing
# Speed: 0.0ms preprocess, 100.6ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 1 Human face, 2 Mans, 103.1ms
# Confidence ---> 0.81
# Class name --> Human face
# Confidence ---> 0.51
# Class name --> Man
# Confidence ---> 0.28
# Class name --> Man
# Confidence ---> 0.28
# Class name --> Clothing
# Speed: 0.0ms preprocess, 103.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 2 Human faces, 1 Man, 2 Womans, 102.0ms
# Confidence ---> 0.85
# Class name --> Human face
# Confidence ---> 0.56
# Class name --> Human face
# Confidence ---> 0.42
# Class name --> Clothing
# Confidence ---> 0.31
# Class name --> Woman
# Confidence ---> 0.3
# Class name --> Man
# Confidence ---> 0.27
# Class name --> Woman
# Speed: 0.0ms preprocess, 102.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 3 Human faces, 1 Man, 1 Woman, 104.0ms
# Confidence ---> 0.84
# Class name --> Human face
# Confidence ---> 0.7
# Class name --> Human face
# Confidence ---> 0.55
# Class name --> Human face
# Confidence ---> 0.43
# Class name --> Man
# Confidence ---> 0.33
# Class name --> Clothing
# Confidence ---> 0.26
# Class name --> Woman
# Speed: 0.0ms preprocess, 104.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Clothings, 3 Human faces, 2 Mans, 1 Woman, 86.2ms
# Confidence ---> 0.86
# Class name --> Human face
# Confidence ---> 0.73
# Class name --> Human face
# Confidence ---> 0.52
# Class name --> Human face
# Confidence ---> 0.46
# Class name --> Man
# Confidence ---> 0.36
# Class name --> Man
# Confidence ---> 0.36
# Class name --> Clothing
# Confidence ---> 0.28
# Class name --> Woman
# Confidence ---> 0.26
# Class name --> Clothing
# Speed: 0.0ms preprocess, 86.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 3 Human faces, 2 Mans, 1 Woman, 102.2ms
# Confidence ---> 0.84
# Class name --> Human face
# Confidence ---> 0.68
# Class name --> Human face
# Confidence ---> 0.53
# Class name --> Clothing
# Confidence ---> 0.5
# Class name --> Man
# Confidence ---> 0.38
# Class name --> Human face
# Confidence ---> 0.37
# Class name --> Man
# Confidence ---> 0.27
# Class name --> Woman
# Speed: 0.0ms preprocess, 102.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 3 Human faces, 1 Man, 2 Womans, 102.2ms
# Confidence ---> 0.83
# Class name --> Human face
# Confidence ---> 0.68
# Class name --> Human face
# Confidence ---> 0.56
# Class name --> Human face
# Confidence ---> 0.48
# Class name --> Man
# Confidence ---> 0.42
# Class name --> Clothing
# Confidence ---> 0.31
# Class name --> Woman
# Confidence ---> 0.29
# Class name --> Woman
# Speed: 0.0ms preprocess, 102.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Clothings, 3 Human faces, 1 Man, 2 Womans, 105.2ms
# Confidence ---> 0.84
# Class name --> Human face
# Confidence ---> 0.71
# Class name --> Human face
# Confidence ---> 0.52
# Class name --> Human face
# Confidence ---> 0.46
# Class name --> Woman
# Confidence ---> 0.46
# Class name --> Clothing
# Confidence ---> 0.45
# Class name --> Man
# Confidence ---> 0.44
# Class name --> Woman
# Confidence ---> 0.28
# Class name --> Clothing
# Speed: 0.0ms preprocess, 105.2ms inference, 15.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 3 Human faces, 1 Man, 1 Woman, 104.6ms
# Confidence ---> 0.82
# Class name --> Human face
# Confidence ---> 0.7
# Class name --> Human face
# Confidence ---> 0.44
# Class name --> Man
# Confidence ---> 0.43
# Class name --> Clothing
# Confidence ---> 0.43
# Class name --> Woman
# Confidence ---> 0.26
# Class name --> Human face
# Speed: 0.0ms preprocess, 104.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 3 Human faces, 2 Mans, 1 Woman, 102.2ms
# Confidence ---> 0.83
# Class name --> Human face
# Confidence ---> 0.67
# Class name --> Human face
# Confidence ---> 0.48
# Class name --> Clothing
# Confidence ---> 0.47
# Class name --> Man
# Confidence ---> 0.36
# Class name --> Woman
# Confidence ---> 0.33
# Class name --> Human face
# Confidence ---> 0.3
# Class name --> Man
# Speed: 0.0ms preprocess, 102.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Clothings, 3 Human faces, 1 Laptop, 1 Man, 1 Woman, 105.0ms
# Confidence ---> 0.84
# Class name --> Human face
# Confidence ---> 0.69
# Class name --> Human face
# Confidence ---> 0.52
# Class name --> Man
# Confidence ---> 0.5
# Class name --> Human face
# Confidence ---> 0.43
# Class name --> Clothing
# Confidence ---> 0.35
# Class name --> Woman
# Confidence ---> 0.31
# Class name --> Laptop
# Confidence ---> 0.3
# Class name --> Clothing
# Speed: 0.0ms preprocess, 105.0ms inference, 15.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Clothings, 3 Human faces, 1 Man, 1 Woman, 104.6ms
# Confidence ---> 0.84
# Class name --> Human face
# Confidence ---> 0.68
# Class name --> Human face
# Confidence ---> 0.49
# Class name --> Clothing
# Confidence ---> 0.47
# Class name --> Man
# Confidence ---> 0.42
# Class name --> Human face
# Confidence ---> 0.34
# Class name --> Woman
# Confidence ---> 0.28
# Class name --> Clothing
# Speed: 0.0ms preprocess, 104.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Clothings, 3 Human faces, 1 Man, 1 Woman, 104.6ms
# Confidence ---> 0.83
# Class name --> Human face
# Confidence ---> 0.65
# Class name --> Human face
# Confidence ---> 0.53
# Class name --> Man
# Confidence ---> 0.5
# Class name --> Clothing
# Confidence ---> 0.42
# Class name --> Woman
# Confidence ---> 0.39
# Class name --> Human face
# Confidence ---> 0.26
# Class name --> Clothing
# Speed: 0.0ms preprocess, 104.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Clothings, 3 Human faces, 1 Man, 1 Woman, 99.1ms
# Confidence ---> 0.86
# Class name --> Human face
# Confidence ---> 0.69
# Class name --> Human face
# Confidence ---> 0.53
# Class name --> Human face
# Confidence ---> 0.45
# Class name --> Clothing
# Confidence ---> 0.44
# Class name --> Man
# Confidence ---> 0.28
# Class name --> Clothing
# Confidence ---> 0.28
# Class name --> Woman
# Speed: 0.0ms preprocess, 99.1ms inference, 16.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Clothings, 3 Human faces, 2 Mans, 105.5ms
# Confidence ---> 0.84
# Class name --> Human face
# Confidence ---> 0.7
# Class name --> Human face
# Confidence ---> 0.49
# Class name --> Man
# Confidence ---> 0.42
# Class name --> Human face
# Confidence ---> 0.39
# Class name --> Clothing
# Confidence ---> 0.27
# Class name --> Clothing
# Confidence ---> 0.27
# Class name --> Man
# Speed: 0.0ms preprocess, 105.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Clothings, 3 Human faces, 2 Mans, 101.8ms
# Confidence ---> 0.85
# Class name --> Human face
# Confidence ---> 0.67
# Class name --> Human face
# Confidence ---> 0.5
# Class name --> Man
# Confidence ---> 0.49
# Class name --> Human face
# Confidence ---> 0.49
# Class name --> Clothing
# Confidence ---> 0.38
# Class name --> Man
# Confidence ---> 0.31
# Class name --> Clothing
# Speed: 0.0ms preprocess, 101.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Clothings, 3 Human faces, 2 Mans, 1 Woman, 102.4ms
# Confidence ---> 0.84
# Class name --> Human face
# Confidence ---> 0.66
# Class name --> Human face
# Confidence ---> 0.49
# Class name --> Man
# Confidence ---> 0.48
# Class name --> Clothing
# Confidence ---> 0.43
# Class name --> Human face
# Confidence ---> 0.41
# Class name --> Man
# Confidence ---> 0.31
# Class name --> Clothing
# Confidence ---> 0.31
# Class name --> Woman
# Speed: 0.0ms preprocess, 102.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Clothings, 3 Human faces, 2 Mans, 102.9ms
# Confidence ---> 0.84
# Class name --> Human face
# Confidence ---> 0.66
# Class name --> Human face
# Confidence ---> 0.46
# Class name --> Clothing
# Confidence ---> 0.46
# Class name --> Man
# Confidence ---> 0.4
# Class name --> Man
# Confidence ---> 0.34
# Class name --> Human face
# Confidence ---> 0.31
# Class name --> Clothing
# Speed: 0.0ms preprocess, 102.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Clothings, 3 Human faces, 2 Mans, 102.3ms
# Confidence ---> 0.85
# Class name --> Human face
# Confidence ---> 0.7
# Class name --> Human face
# Confidence ---> 0.52
# Class name --> Clothing
# Confidence ---> 0.48
# Class name --> Human face
# Confidence ---> 0.48
# Class name --> Man
# Confidence ---> 0.44
# Class name --> Man
# Confidence ---> 0.26
# Class name --> Clothing
# Speed: 0.0ms preprocess, 102.3ms inference, 15.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 3 Human faces, 2 Mans, 1 Woman, 102.2ms
# Confidence ---> 0.86
# Class name --> Human face
# Confidence ---> 0.7
# Class name --> Human face
# Confidence ---> 0.56
# Class name --> Clothing
# Confidence ---> 0.53
# Class name --> Human face
# Confidence ---> 0.43
# Class name --> Man
# Confidence ---> 0.43
# Class name --> Man
# Confidence ---> 0.32
# Class name --> Woman
# Speed: 0.0ms preprocess, 102.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 3 Human faces, 2 Mans, 1 Woman, 104.0ms
# Confidence ---> 0.84
# Class name --> Human face
# Confidence ---> 0.68
# Class name --> Human face
# Confidence ---> 0.53
# Class name --> Clothing
# Confidence ---> 0.51
# Class name --> Human face
# Confidence ---> 0.46
# Class name --> Man
# Confidence ---> 0.46
# Class name --> Man
# Confidence ---> 0.26
# Class name --> Woman
# Speed: 0.0ms preprocess, 104.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 3 Human faces, 3 Mans, 117.6ms
# Confidence ---> 0.83
# Class name --> Human face
# Confidence ---> 0.66
# Class name --> Human face
# Confidence ---> 0.55
# Class name --> Clothing
# Confidence ---> 0.47
# Class name --> Man
# Confidence ---> 0.47
# Class name --> Man
# Confidence ---> 0.47
# Class name --> Human face
# Confidence ---> 0.26
# Class name --> Man
# Speed: 0.0ms preprocess, 117.6ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 3 Human faces, 3 Mans, 1 Woman, 102.1ms
# Confidence ---> 0.85
# Class name --> Human face
# Confidence ---> 0.69
# Class name --> Human face
# Confidence ---> 0.57
# Class name --> Clothing
# Confidence ---> 0.5
# Class name --> Man
# Confidence ---> 0.44
# Class name --> Human face
# Confidence ---> 0.41
# Class name --> Man
# Confidence ---> 0.31
# Class name --> Woman
# Confidence ---> 0.29
# Class name --> Man
# Speed: 0.0ms preprocess, 102.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 3 Human faces, 2 Mans, 83.9ms
# Confidence ---> 0.86
# Class name --> Human face
# Confidence ---> 0.73
# Class name --> Human face
# Confidence ---> 0.52
# Class name --> Clothing
# Confidence ---> 0.51
# Class name --> Human face
# Confidence ---> 0.46
# Class name --> Man
# Confidence ---> 0.43
# Class name --> Man
# Speed: 0.0ms preprocess, 83.9ms inference, 15.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Clothings, 3 Human faces, 3 Mans, 104.2ms
# Confidence ---> 0.86
# Class name --> Human face
# Confidence ---> 0.69
# Class name --> Human face
# Confidence ---> 0.6
# Class name --> Man
# Confidence ---> 0.53
# Class name --> Clothing
# Confidence ---> 0.51
# Class name --> Man
# Confidence ---> 0.39
# Class name --> Human face
# Confidence ---> 0.29
# Class name --> Clothing
# Confidence ---> 0.29
# Class name --> Man
# Speed: 0.0ms preprocess, 104.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Clothings, 3 Human faces, 2 Mans, 102.7ms
# Confidence ---> 0.85
# Class name --> Human face
# Confidence ---> 0.7
# Class name --> Human face
# Confidence ---> 0.53
# Class name --> Clothing
# Confidence ---> 0.49
# Class name --> Man
# Confidence ---> 0.41
# Class name --> Man
# Confidence ---> 0.3
# Class name --> Human face
# Confidence ---> 0.27
# Class name --> Clothing
# Speed: 0.0ms preprocess, 102.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Clothings, 3 Human faces, 2 Mans, 102.1ms
# Confidence ---> 0.86
# Class name --> Human face
# Confidence ---> 0.69
# Class name --> Human face
# Confidence ---> 0.53
# Class name --> Man
# Confidence ---> 0.5
# Class name --> Clothing
# Confidence ---> 0.46
# Class name --> Man
# Confidence ---> 0.46
# Class name --> Human face
# Confidence ---> 0.28
# ...
# Speed: 2.0ms preprocess, 107.0ms inference, 10.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 3 Human faces, 3 Mans, 119.3ms
# Confidence ---> 0.86
# Class name --> Human face
# Confidence ---> 0.56
# Class name --> Man
# Confidence ---> 0.53
# Class name --> Clothing
# Confidence ---> 0.47
# Class name --> Human face
# Confidence ---> 0.38
# Class name --> Human face
# Confidence ---> 0.32
# Class name --> Man
# Confidence ---> 0.28
# Class name --> Man
# Speed: 3.0ms preprocess, 119.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 2 Human faces, 3 Mans, 120.9ms
# Confidence ---> 0.87
# Class name --> Human face
# Confidence ---> 0.64
# Class name --> Man
# Confidence ---> 0.53
# Class name --> Clothing
# Confidence ---> 0.53
# Class name --> Human face
# Confidence ---> 0.29
# Class name --> Man
# Confidence ---> 0.27
# Class name --> Man
# Speed: 0.0ms preprocess, 120.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 2 Human faces, 3 Mans, 154.6ms
# Confidence ---> 0.86
# Class name --> Human face
# Confidence ---> 0.56
# Class name --> Man
# Confidence ---> 0.55
# Class name --> Clothing
# Confidence ---> 0.53
# Class name --> Human face
# Confidence ---> 0.35
# Class name --> Man
# Confidence ---> 0.28
# Class name --> Man
# Speed: 0.0ms preprocess, 154.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 2 Human faces, 2 Mans, 138.4ms
# Confidence ---> 0.85
# Class name --> Human face
# Confidence ---> 0.53
# Class name --> Clothing
# Confidence ---> 0.47
# Class name --> Man
# Confidence ---> 0.44
# Class name --> Human face
# Confidence ---> 0.28
# Class name --> Man
# Speed: 0.0ms preprocess, 138.4ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 2 Human faces, 2 Mans, 1 Woman, 130.0ms
# Confidence ---> 0.87
# Class name --> Human face
# Confidence ---> 0.53
# Class name --> Clothing
# Confidence ---> 0.46
# Class name --> Man
# Confidence ---> 0.38
# Class name --> Human face
# Confidence ---> 0.33
# Class name --> Man
# Confidence ---> 0.31
# Class name --> Woman
# Speed: 3.0ms preprocess, 130.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 2 Human faces, 3 Mans, 111.3ms
# Confidence ---> 0.87
# Class name --> Human face
# Confidence ---> 0.57
# Class name --> Man
# Confidence ---> 0.52
# Class name --> Clothing
# Confidence ---> 0.48
# Class name --> Human face
# Confidence ---> 0.31
# Class name --> Man
# Confidence ---> 0.29
# Class name --> Man
# Speed: 0.0ms preprocess, 111.3ms inference, 9.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 2 Human faces, 2 Mans, 120.6ms
# Confidence ---> 0.87
# Class name --> Human face
# Confidence ---> 0.64
# Class name --> Man
# Confidence ---> 0.54
# Class name --> Clothing
# Confidence ---> 0.45
# Class name --> Human face
# Confidence ---> 0.29
# Class name --> Man
# Speed: 0.0ms preprocess, 120.6ms inference, 15.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 2 Human faces, 3 Mans, 136.5ms
# Confidence ---> 0.86
# Class name --> Human face
# Confidence ---> 0.67
# Class name --> Man
# Confidence ---> 0.53
# Class name --> Clothing
# Confidence ---> 0.52
# Class name --> Human face
# Confidence ---> 0.33
# Class name --> Man
# Confidence ---> 0.26
# Class name --> Man
# Speed: 0.0ms preprocess, 136.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 2 Human faces, 3 Mans, 150.3ms
# Confidence ---> 0.87
# Class name --> Human face
# Confidence ---> 0.64
# Class name --> Man
# Confidence ---> 0.52
# Class name --> Clothing
# Confidence ---> 0.42
# Class name --> Human face
# Confidence ---> 0.37
# Class name --> Man
# Confidence ---> 0.26
# Class name --> Man
# Speed: 0.0ms preprocess, 150.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 3 Human faces, 2 Mans, 137.9ms
# Confidence ---> 0.87
# Class name --> Human face
# Confidence ---> 0.64
# Class name --> Man
# Confidence ---> 0.54
# Class name --> Clothing
# Confidence ---> 0.46
# Class name --> Human face
# Confidence ---> 0.42
# Class name --> Man
# Confidence ---> 0.3
# Class name --> Human face
# Speed: 3.3ms preprocess, 137.9ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 2 Human faces, 2 Mans, 130.5ms
# Confidence ---> 0.86
# Class name --> Human face
# Confidence ---> 0.6
# Class name --> Man
# Confidence ---> 0.53
# Class name --> Clothing
# Confidence ---> 0.4
# Class name --> Man
# Confidence ---> 0.39
# Class name --> Human face
# Speed: 0.0ms preprocess, 130.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 3 Human faces, 2 Mans, 106.1ms
# Confidence ---> 0.85
# Class name --> Human face
# Confidence ---> 0.75
# Class name --> Man
# Confidence ---> 0.54
# Class name --> Clothing
# Confidence ---> 0.46
# Class name --> Man
# Confidence ---> 0.39
# Class name --> Human face
# Confidence ---> 0.33
# Class name --> Human face
# Speed: 0.0ms preprocess, 106.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 2 Human faces, 2 Mans, 105.3ms
# Confidence ---> 0.86
# Class name --> Human face
# Confidence ---> 0.63
# Class name --> Man
# Confidence ---> 0.51
# Class name --> Clothing
# Confidence ---> 0.44
# Class name --> Human face
# Confidence ---> 0.3
# Class name --> Man
# Speed: 0.0ms preprocess, 105.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Clothing, 2 Human faces, 2 Mans, 102.2ms
# Confidence ---> 0.86
# Class name --> Human face
# Confidence ---> 0.59
# Class name --> Man
# Confidence ---> 0.53
# Class name --> Clothing
# Confidence ---> 0.5
# Class name --> Human face
# Confidence ---> 0.3
# Class name --> Man
# Speed: 0.0ms preprocess, 102.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 93
#      90 results = model(img, stream=True)
#      92 # coordinates
# ---> 93 for r in results:
#      94     boxes = r.boxes
#      96     for box in boxes:
#      97         # bounding box
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\utils\_contextlib.py:36, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      33 try:
#      34     # Issuing `None` to a generator fires it up
#      35     with ctx_factory():
# ---> 36         response = gen.send(None)
#      38     while True:
#      39         try:
#      40             # Forward the response to our caller and get its next request
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ultralytics\engine\predictor.py:255, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     253 # Inference
#     254 with profilers[1]:
# --> 255     preds = self.inference(im, *args, **kwargs)
#     256     if self.args.embed:
#     257         yield from [preds] if isinstance(preds, torch.Tensor) else preds  # yield embedding tensors
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ultralytics\engine\predictor.py:143, in BasePredictor.inference(self, im, *args, **kwargs)
#     137 """Runs inference on a given image using the specified model and arguments."""
#     138 visualize = (
#     139     increment_path(self.save_dir / Path(self.batch[0][0]).stem, mkdir=True)
#     140     if self.args.visualize and (not self.source_type.tensor)
#     141     else False
#     142 )
# --> 143 return self.model(im, augment=self.args.augment, visualize=visualize, embed=self.args.embed, *args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ultralytics\nn\autobackend.py:510, in AutoBackend.forward(self, im, augment, visualize, embed)
#     508 # PyTorch
#     509 if self.pt or self.nn_module:
# --> 510     y = self.model(im, augment=augment, visualize=visualize, embed=embed)
#     512 # TorchScript
#     513 elif self.jit:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ultralytics\nn\tasks.py:112, in BaseModel.forward(self, x, *args, **kwargs)
#     110 if isinstance(x, dict):  # for cases of training and validating while training.
#     111     return self.loss(x, *args, **kwargs)
# --> 112 return self.predict(x, *args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ultralytics\nn\tasks.py:130, in BaseModel.predict(self, x, profile, visualize, augment, embed)
#     128 if augment:
#     129     return self._predict_augment(x)
# --> 130 return self._predict_once(x, profile, visualize, embed)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ultralytics\nn\tasks.py:151, in BaseModel._predict_once(self, x, profile, visualize, embed)
#     149 if profile:
#     150     self._profile_one_layer(m, x, dt)
# --> 151 x = m(x)  # run
#     152 y.append(x if m.i in self.save else None)  # save output
#     153 if visualize:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ultralytics\nn\modules\head.py:69, in Detect.forward(self, x)
#      66     return self.forward_end2end(x)
#      68 for i in range(self.nl):
# ---> 69     x[i] = torch.cat((self.cv2[i](x[i]), self.cv3[i](x[i])), 1)
#      70 if self.training:  # Training path
#      71     return x
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\container.py:219, in Sequential.forward(self, input)
#     217 def forward(self, input):
#     218     for module in self:
# --> 219         input = module(input)
#     220     return input
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\ultralytics\nn\modules\conv.py:54, in Conv.forward_fuse(self, x)
#      52 def forward_fuse(self, x):
#      53     """Perform transposed convolution of 2D data."""
# ---> 54     return self.act(self.conv(x))
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\conv.py:458, in Conv2d.forward(self, input)
#     457 def forward(self, input: Tensor) -> Tensor:
# --> 458     return self._conv_forward(input, self.weight, self.bias)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\conv.py:454, in Conv2d._conv_forward(self, input, weight, bias)
#     450 if self.padding_mode != 'zeros':
#     451     return F.conv2d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#     452                     weight, bias, self.stride,
#     453                     _pair(0), self.dilation, self.groups)
# --> 454 return F.conv2d(input, weight, bias, self.stride,
#     455                 self.padding, self.dilation, self.groups)
#
# KeyboardInterrupt:

# %% [markdown]
# Ici, le résultat peut être bien plus mitigé, comme avec l'exemple suivant où la catégorie est approximative selon la position du sujet. On peut le voir sur cette image avec la confusion man/woman (les deux sont superposés, le modèle a donc du mal à trancher) :
#
#
# ## 3 - Transfer Learning YOLO V8 :
# Ici, nous allons partir de la base du modèle YOLO V8 pour lui faire apprendre seulement 3 nouvelles catégories, celles existantes (les 80) seront remplacé par : *waterbottle*, *can* et *snackbar*.
# Le code suivant permet d'utiliser le modèle existant pour effectuer un transfer learning et ajouter les catégories nécessaires :

# %%
# Charger le modèle pré-entrainé
model = YOLO("yolo-Weights/yolov8n.pt")

# Réinitialiser les classes pour correspondre à vos nouvelles classes
model.reset_head(num_classes=3)  # Vos nouvelles classes uniquement

# Lancer l'entraînement avec les nouvelles données
model.train(data="data.yaml", epochs=50, imgsz=640, batch=16)

# %% [markdown]
# Attention, vous trouverez ci-joint le fichier data.yaml, qu'il faut modifier à chaque modification du modèle.

# %% [markdown]
# Nous utilisons un dataset découpé en 3 catégories : *train*, *valid* et *test* afin d'apprendre à reconnaître les objets visés.Il faut que dans chaque dossiers, il y ai 2 sous dossier, un pour les images et un pour les labels de chaque image. Les fichiers labels contiennent l'indice de la classe correspondante (ici 0 = can, 1 = snackbag et 2 = waterbottle), les coordonnées x et y du centre de l'objet, la largeur et la hauteur de la box de l'objet.
#
# Le résultat se présente sous de forme de deux fichiers : *best.pt* et *last.pt*. En les utilisant comme modèles, on peut désormais reconnaître les trois catégories ajoutées.
#
# Exemple avant utilisation du best.pt :
# ![img.png](CR_images/img.png)
# HERE IMAGE BOITE 2 conserv pas reconnue
#
# ![img.png](CR_images/img.png)
# HERE IMAGE BOITE 2 conserv reconnue
#
# Le code reste très similaire pour l'utilisation du nouveau modèle :

# %%
# start webcam
cap = cv2.VideoCapture(0)
cap.set(3, 640)
cap.set(4, 480)

# model
model = YOLO("runs/detect/train/weights/best.pt")

classNames = ["can", "snackbag", "waterbottle"]

while True:
    success, img = cap.read()
    results = model(img, stream=True)

    # coordinates
    for r in results:
        boxes = r.boxes

        for box in boxes:
            # bounding box
            x1, y1, x2, y2 = box.xyxy[0]
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)  # convert to int values

            # put box in cam
            cv2.rectangle(img, (x1, y1), (x2, y2), (255, 255, 0), 2)

            # confidence
            confidence = math.ceil((box.conf[0] * 100)) / 100
            print("Confidence --->", confidence)

            # class name
            cls = int(box.cls[0])
            print("Class name -->", classNames[cls])

            # object details
            org = [x1, y1]
            font = cv2.FONT_HERSHEY_SIMPLEX
            fontScale = 1
            color = (255, 0, 0)
            thickness = 2

            cv2.putText(img, classNames[cls] + " : " + str(confidence), org, font, fontScale, color, thickness)

    cv2.imshow('Webcam', img)
    if cv2.waitKey(1) == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
